# %%
# ENV (NLP)

# %% [markdown]
# # 0. Read Source Data & Preprocessing

# %%
import pandas as pd

# %%
data = pd.read_excel('./data/3415_All_STORIES_Updated_ver02.xlsx', index_col = None, header = 0)

# %%
# Function to extract story content after the names
def extract_story(text):
    # Step 1: Split the text by line breaks
    lines = text.strip().split('\n')

    # Step 2: Detect the start of the story (the first longer segment, which should be a complete sentence)
    story_started = False
    story_lines = []
    
    for line in lines:
        # If the line contains more than a few words (let's say more than 3), assume it's the start of the story
        if len(line.split()) > 3:
            story_started = True
        # Once we detect the start of the story, append the rest of the lines
        if story_started:
            story_lines.append(line)
    
    # Step 3: Combine the story lines into a single string and return the result
    return ' '.join(story_lines).strip()

# %%
data['STORY TEXT'] = data['STORY TEXT'].apply(extract_story)

# %%
# we have
# 3414 of stories
data
# Out:
#       STORY ID                                         STORY TEXT
# 0          1.0  Ludwig Wörl (1906-1967) spent 11 years of his ...
# 1          2.0  Johann Pscheidt was born in the city of Radaut...
# 2          3.0  Even before the war, Professor Tadeusz Czeżows...
# 3          4.0  During the occupation, Władysław Kowalski, a q...
# 4          6.0  Władysława Choms, the wife of a major in the P...
# ...        ...                                                ...
# 3409   13524.0  Mordechai Wulkan (b. 1910) and his wife, Chaja...
# 3410   13611.0  Sala Armel-Goldhar lived with her parents, Isr...
# 3411    5257.0  Following Helena Zienowicz’s graduation from t...
# 3412    3053.0  Before the war, Badowski Stefan Franciszek liv...
# 3413    4481.0  In July 1942, during the large-scale Aktion in...
#
# [3414 rows x 2 columns]

# %% [markdown]
# # 1. Milestone 1: Find Names - NER & Co-reference Resolution

# %% [markdown]
# ## 1.1 Find all Names: Simple NER: Start with SPACY Package and model “en_core_web_md” + "en_coreference_web_trf"

# %%
import spacy
import neuralcoref
from spacy import displacy

# %%
# !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.4.1/en_core_web_md-3.4.1-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 26.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from en-core-web-md==3.4.1) (3.4.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (8.1.12)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.7.0)
# Requirement already satisfied: pathy>=0.3.5 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (4.66.5)
# Requirement already satisfied: numpy>=1.15.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.10.18)
# Requirement already satisfied: jinja2 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.1.4)
# Requirement already satisfied: setuptools in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.4.0)
# Requirement already satisfied: language-data>=1.2 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.2.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.2.0)
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.4.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
# Load SpaCy's English model
nlp = spacy.load('en_core_web_md')

# Add neuralcoref to SpaCy's pipeline
neuralcoref.add_to_pipe(nlp)

# %% [markdown]
# ## Coreference Resolution

# %%
# import tqdm to track a progress
from tqdm import tqdm
tqdm.pandas()

# %%
# Sampling data
data = data[:20]

# %%
data
# Out:
#     STORY ID                                         STORY TEXT
# 0        1.0  Ludwig Wörl (1906-1967) spent 11 years of his ...
# 1        2.0  Johann Pscheidt was born in the city of Radaut...
# 2        3.0  Even before the war, Professor Tadeusz Czeżows...
# 3        4.0  During the occupation, Władysław Kowalski, a q...
# 4        6.0  Władysława Choms, the wife of a major in the P...
# 5        7.0  At various times during the occupation, Ludwik...
# 6        8.0  Hauptmann Hans Hartmann, aged 40, was one of t...
# 7       11.0  Gertruda Babilinska was born in 1902 in Starog...
# 8       13.0  Edward Chacza, who lived in Baranowicze in the...
# 9       14.0  During the war, Domna Semenyuk was a farmer li...
# 10      15.0  In 1942, the Czajkowskis’ Jewish neighbors wer...
# 11      16.0  During the war, Władysław Wójcik lived with hi...
# 12      19.0  Vasiliy Lopatinskiy, in his 70s, lived and wor...
# 13      20.0  Oskar Schindler was born on April 28, 1908 at ...
# 14      21.0  Vienna-born Julius Madritsch was an expert in ...
# 15      22.0  Upon the German invasion of the township of Ka...
# 16      23.0  Vienna-born Oswald Bouska (called in some sour...
# 17      29.0  From September 1942, even before the establish...
# 18      30.0  During the occupation, the author Maria Kann o...
# 19      33.0  Three months after Hitler’s rise to power, in ...

# %%
data['STORY TEXT'] = data['STORY TEXT'].progress_apply(lambda row : nlp(row)._.coref_resolved)
# Out:
# 100%|██████████| 20/20 [00:20<00:00,  1.03s/it]
# /Users/minjoo/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data['STORY TEXT'][0]
# Out:
# 'Ludwig Wörl (1906-1967) spent 11 years of Ludwig Wörl (1906-1967) life as a political prisoner in Nazi concentration camps.  Ludwig Wörl (1906-1967) was first arrested by the Gestapo in 1934, and sent to Dachau for distributing a pamphlet in which the citizens of Munich were informed about the horrors of the camp. After spending some nine months in a dark detention cell, Ludwig Wörl (1906-1967) was first transferred to the camp’s joinery and later, as a trained medical orderly, assigned to the camp’s sick-bay. In 1942, Ludwig Wörl (1906-1967) was sent to Auschwitz together with 17 other male nurses to deal with an outbreak of typhus, which threatened not only the prisoners but also the German camp personnel. Appointed as the Lagerälteste (the camp elder) of the hospital barracks, Wörl, against the express orders of the SS, employed Jewish doctors, thus saving Jewish doctors from certain death. Ludwig Wörl (1906-1967) also put Ludwig Wörl (1906-1967) at risk in order to obtain at least a minimum of the required medicines and medical instruments for the treatment of the sick. Ludwig Wörl (1906-1967) would forge selection lists in order to save Jewish patients from death by gassing. As a result of consistently countermanding the orders of the SS doctors aimed at decimating the number of the sick, Wörl was dismissed from Wörl post and incarcerated once again in an isolated detention cell. After a while Wörl was released and, by virtue of Wörl German descent and seniority, put in charge of Güntergrube, a forced-labor camp near Auschwitz. Here, again, Wörl made Wörl beneficial influence felt, protecting the 600 Jewish prisoners from maltreatment by sadistic German Kapos and seeing to it that the 600 Jewish prisoners get the 600 Jewish prisoners due share of food and clothing. Even prisoners with tuberculosis were able to survive because Wörl exempted Even prisoners with tuberculosis from hard work and protected Even prisoners with tuberculosis by various subterfuges from the inspection of the SS doctors. At the time of the evacuation of Auschwitz, Wörl helped prisoners escape from the infamous death marches. After the war Wörl, who became chairman of the Organization of Former Auschwitz Prisoners in Germany, dedicated Wörl life to perpetuating the memory of the Nazi crimes and bringing the Nazi crimes perpetrators to justice. In 1963, Wörl took the stand as one of the key witnesses in the Auschwitz trial in Frankfurt am Main. On March 19, 1963, Yad Vashem recognized Ludwig Wörl as Righteous Among the Nations.'

# %%
data.to_csv('./drafts/3415_all_coref_data.csv', index = False)

# %%
data = pd.read_csv('/drafts/3415_all_coref_data.csv')

# %% [markdown]
# ### Separate into sentences, find Named Entity (PERSON) and make a dataframe

# %%
table_1 = pd.DataFrame(columns = ['storynumber', 'name', 'sentence'])

# %%
for id, story in zip(data['STORY ID'], data['STORY TEXT']):
    sentences = [i for i in nlp(story).sents]
    for sentence in sentences:
        for entity in sentence.ents:
            if entity.label_ == 'PERSON':
                stc = str(sentence)
                new_row = {'storynumber' : id, 'name' : entity.text, 'sentence' : stc}
                table_1.loc[len(table_1)] = new_row

# %%
table_1
# Out:
#      storynumber           name  \
# 0            1.0    Ludwig Wörl
# 1            1.0    Ludwig Wörl
# 2            1.0    Ludwig Wörl
# 3            1.0    Ludwig Wörl
# 4            1.0    Ludwig Wörl
# ..           ...            ...
# 591         33.0        Strauss
# 592         33.0        Strauss
# 593         33.0  Werner Krumme
# 594         33.0         Vashem
# 595         33.0  Werner Krumme
#
#                                               sentence
# 0    Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 1    Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 2    Ludwig Wörl (1906-1967) was first arrested by ...
# 3    After spending some nine months in a dark dete...
# 4    In 1942, Ludwig Wörl (1906-1967) was sent to A...
# ..                                                 ...
# 591  The Jewish pharmacist Strauss was likewise ass...
# 592  The Jewish pharmacist Strauss was likewise ass...
# 593  Werner Krumme himself was released from Auschw...
# 594  On June 16, 1964, Yad Vashem recognized Werner...
# 595  On June 16, 1964, Yad Vashem recognized Werner...
#
# [596 rows x 3 columns]

# %%
# Extract Output
table_1.to_csv('./output/3415_SPACY_All_Names.xlsx', index = False)

# %%
table_1 = pd.read_csv('./output/3415_SPACY_All_Names.xlsx')

# %% [markdown]
# ## 1.2 Find Rescuers Names: Filtering Only Rescuers (Righteous Among the Nations) Names

# %% [markdown]
# ### 1.2.1.1 Step 1: Preparing a table of filtered sentences: “Rescuing Phrases-Name” - Lexicon-based

# %%
# Table 1
table_1
# table1 = pd.read_excel('./output/3415_SPACY_All_Names.xlsx', index = False)
# Out:
#      storynumber           name  \
# 0            1.0    Ludwig Wörl
# 1            1.0    Ludwig Wörl
# 2            1.0    Ludwig Wörl
# 3            1.0    Ludwig Wörl
# 4            1.0    Ludwig Wörl
# ..           ...            ...
# 591         33.0        Strauss
# 592         33.0        Strauss
# 593         33.0  Werner Krumme
# 594         33.0         Vashem
# 595         33.0  Werner Krumme
#
#                                               sentence
# 0    Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 1    Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 2    Ludwig Wörl (1906-1967) was first arrested by ...
# 3    After spending some nine months in a dark dete...
# 4    In 1942, Ludwig Wörl (1906-1967) was sent to A...
# ..                                                 ...
# 591  The Jewish pharmacist Strauss was likewise ass...
# 592  The Jewish pharmacist Strauss was likewise ass...
# 593  Werner Krumme himself was released from Auschw...
# 594  On June 16, 1964, Yad Vashem recognized Werner...
# 595  On June 16, 1964, Yad Vashem recognized Werner...
#
# [596 rows x 3 columns]

# %%
table_1.iloc[17]
# Out:
# storynumber                                                  1.0
# name                                                        Wörl
# sentence       After the war Wörl, who became chairman of the...
# Name: 17, dtype: object

# %%
# Table 2 (lexicon)
table_2 = pd.read_excel('./data/Final_Lexicon_Updated.xlsx')

# %%
table_2
# Out:
#       Story ID        Rescuing Verb  \
# 0          1.0                 sent
# 1          1.0                 sent
# 2          1.0             employed
# 3          1.0               saving
# 4          1.0  put himself at risk
# ...        ...                  ...
# 8922    5257.0         looked after
# 8923    5257.0         looked after
# 8924    5257.0            sheltered
# 8925    5257.0             obtained
# 8926    5257.0               taught
#
#                                         Rescuing Phrase
# 0     his life as a political prisoner in nazi conce...
# 1     to the camp’s joinery and later, as a trained ...
# 2     personnel. appointed as the lagerälteste (the ...
# 3     lagerälteste (the camp elder) of the hospital ...
# 4     barracks, wörl, against the express orders of ...
# ...                                                 ...
# 8922  Helena looked after the children, obtaining "A...
# 8923  Helena looked after the children, obtaining "A...
# 8924  Initially, they were only supposed to stay wit...
# 8925  Helenapresented the fugitives as her brother’s...
# 8926  Helenapresented the fugitives as her brother’s...
#
# [8927 rows x 3 columns]

# %%
data.columns = ['Story ID', 'Story Text']

# %%
data
# Out:
#     Story ID                                         Story Text
# 0        1.0  Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 1        2.0  Johann Pscheidt was born in the city of Radaut...
# 2        3.0  Even before the war, Professor Tadeusz Czeżows...
# 3        4.0  During the occupation, Władysław Kowalski, a q...
# 4        6.0  Władysława Choms, the wife of a major in the P...
# 5        7.0  At various times during the occupation, Ludwik...
# 6        8.0  Hauptmann Hans Hartmann, aged 40, was one of t...
# 7       11.0  Gertruda Babilinska was born in 1902 in Starog...
# 8       13.0  Edward Chacza, who lived in Baranowicze in the...
# 9       14.0  During the war, Domna Semenyuk was a farmer li...
# 10      15.0  In 1942, the Czajkowskis’ Jewish neighbors wer...
# 11      16.0  During the war, Władysław Wójcik lived with Wł...
# 12      19.0  Vasiliy Lopatinskiy, in Vasiliy Lopatinskiy 70...
# 13      20.0  Oskar Schindler was born on April 28, 1908 at ...
# 14      21.0  Vienna-born Julius Madritsch was an expert in ...
# 15      22.0  Upon the German invasion of the township of Ka...
# 16      23.0  Vienna-born Oswald Bouska (called in some sour...
# 17      29.0  From September 1942, even before the establish...
# 18      30.0  During the occupation, Kann organized the Scou...
# 19      33.0  Three months after Hitler’s rise to power, in ...

# %% [markdown]
# #### Trying rescuing verb 등장하는 부분을 lexicon 의 Rescuing Phrase 활용해서 Story 에서 찾기 중인데 쉽지않음

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# /Users/minjoo/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# Step 1: Merge the two dataframes on 'STORY ID'
merged_df = pd.merge(table_2, data, on='Story ID')

# %%
# Step 2: Function to find and replace 'Rescuing Phrase' with the best match in 'STORY TEXT'
def update_rescuing_phrase(row):
    story_text = row['Story Text']
    rescuing_phrase = row['Rescuing Phrase']
    
    # Split the STORY TEXT into sentences
    sentences = story_text.split('. ')
    
    # Split the Rescuing Phrase into its own sentences for matching
    rescuing_sentences = rescuing_phrase.split('. ')
    
    # Track which sentences should be updated
    updated_sentences = []
    
    # Iterate through each rescuing sentence and match it to sentences in the story
    for resc_sentence in rescuing_sentences:
        match = process.extractOne(resc_sentence, sentences, scorer=fuzz.partial_ratio)
        
        # If a good match is found, replace the matched sentence with the rescuing sentence
        if match and match[1] > 80:  # You can adjust the threshold as needed
            matched_sentence = match[0]
            updated_sentences.append(matched_sentence)
            sentences[sentences.index(matched_sentence)] = resc_sentence  # Replace in STORY TEXT
            
    # Join the updated sentences back together
    return '. '.join(sentences)

# %%
# Step 3: Apply the function to each row to update the 'Rescuing Phrase'
merged_df['Updated Rescuing Phrase'] = merged_df.apply(update_rescuing_phrase, axis=1)

# %%
merged_df
# Out:
#     Story ID        Rescuing Verb  \
# 0        1.0                 sent
# 1        1.0                 sent
# 2        1.0             employed
# 3        1.0               saving
# 4        1.0  put himself at risk
# ..       ...                  ...
# 84      29.0                 sent
# 85      29.0              helping
# 86      29.0               helped
# 87      30.0                 sent
# 88      33.0                 sent
#
#                                       Rescuing Phrase  \
# 0   his life as a political prisoner in nazi conce...
# 1   to the camp’s joinery and later, as a trained ...
# 2   personnel. appointed as the lagerälteste (the ...
# 3   lagerälteste (the camp elder) of the hospital ...
# 4   barracks, wörl, against the express orders of ...
# ..                                                ...
# 84  feiner, the bund representative and adolf berm...
# 85  in december 1942, bartoszewski (whose undercov...
# 86  the polish public. he published many articles ...
# 87  the world looks on”), describing the warsaw gh...
# 88  his wife were held in prison in germany until ...
#
#                                            Story Text  \
# 0   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 1   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 2   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 3   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 4   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# ..                                                ...
# 84  From September 1942, even before the establish...
# 85  From September 1942, even before the establish...
# 86  From September 1942, even before the establish...
# 87  During the occupation, Kann organized the Scou...
# 88  Three months after Hitler’s rise to power, in ...
#
#                               Updated Rescuing Phrase
# 0   his life as a political prisoner in nazi conce...
# 1   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 2   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 3   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 4   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# ..                                                ...
# 84  the. When Zegota was established in December 1...
# 85  From September 1942, even before the establish...
# 86  From September 1942, even before the establish...
# 87  During the occupation, Kann organized the Scou...
# 88  Three months after Hitler’s rise to power, in ...
#
# [89 rows x 5 columns]

# %%
merged_df.iloc[-1]['Rescuing Phrase']
# Out:
# 'his wife were held in prison in germany until january 31, 1943, and then deported to auschwitz. mrs. krumme was sent to the gas chambers. an ss-man notified werner of her death, in may 1943, with the following words: “be happy'

# %%
merged_df.iloc[-1]['Updated Rescuing Phrase']
# Out:
# 'Three months after Hitler’s rise to power, in May 1933, Werner Krumme (b. 1909 in Dortmund) married a Jewish wife. Despite official discrimination and frequent harassment by the Gestapo, Krumme stood by Krumme and refused to divorce a Jewish wife. mrs. Krumme, Renate and Anita Lasker, to flee to unoccupied France. his wife were held in prison in germany until january 31, 1943, and then deported to auschwitz. krumme was sent to the gas chambers. an ss-man notified werner of her death, in may 1943, with the following words: “be happy.  Werner used Werner position to falsify so-called selection lists and to assign Jews to work units with relatively tolerable conditions, which increased the chances of Jews survival. Werner thus added the names of Ernst Krinski and Peter Schwartz to a list of a transport that was leaving Auschwitz to the concentration camp of “Warschau,” where no gassing of prisoners took place. The Jewish pharmacist Strauss was likewise assigned by The Jewish pharmacist Strauss to the SS pharmacy in Auschwitz, where The Jewish pharmacist Strauss was able to survive. Werner Krumme himself was released from Auschwitz on July 7, 1944. On June 16, 1964, Yad Vashem recognized Werner Krumme himself as Righteous Among the Nations.'

# %%
# Step 2: Function to find and replace 'Rescuing Phrase' in 'STORY TEXT'
def replace_rescuing_phrase(row):
    story_text = row['Story Text']
    rescuing_phrase = row['Rescuing Phrase']
    
    # Find the closest matching sentence in the STORY TEXT using fuzzy matching
    match = process.extractOne(rescuing_phrase, story_text.split('. '), scorer=fuzz.partial_ratio)
    
    # If a match is found, replace it with the rescuing phrase
    if match and match[1] > 80:  # Match score should be high enough, e.g., above 80
        matched_sentence = match[0]
        new_story_text = story_text.replace(matched_sentence, rescuing_phrase)
        return new_story_text
    else:
        return story_text  # If no good match, return the original story text

# %%
# Step 3: Apply the function to each row to replace the rescuing phrase
merged_df['Updated STORY TEXT'] = merged_df.apply(replace_rescuing_phrase, axis=1)

# %%
merged_df
# Out:
#     Story ID        Rescuing Verb  \
# 0        1.0                 sent
# 1        1.0                 sent
# 2        1.0             employed
# 3        1.0               saving
# 4        1.0  put himself at risk
# ..       ...                  ...
# 84      29.0                 sent
# 85      29.0              helping
# 86      29.0               helped
# 87      30.0                 sent
# 88      33.0                 sent
#
#                                       Rescuing Phrase  \
# 0   his life as a political prisoner in nazi conce...
# 1   to the camp’s joinery and later, as a trained ...
# 2   personnel. appointed as the lagerälteste (the ...
# 3   lagerälteste (the camp elder) of the hospital ...
# 4   barracks, wörl, against the express orders of ...
# ..                                                ...
# 84  feiner, the bund representative and adolf berm...
# 85  in december 1942, bartoszewski (whose undercov...
# 86  the polish public. he published many articles ...
# 87  the world looks on”), describing the warsaw gh...
# 88  his wife were held in prison in germany until ...
#
#                                            Story Text  \
# 0   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 1   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 2   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 3   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 4   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# ..                                                ...
# 84  From September 1942, even before the establish...
# 85  From September 1942, even before the establish...
# 86  From September 1942, even before the establish...
# 87  During the occupation, Kann organized the Scou...
# 88  Three months after Hitler’s rise to power, in ...
#
#                                    Updated STORY TEXT
# 0   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 1   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 2   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 3   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 4   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# ..                                                ...
# 84  From September 1942, even before the establish...
# 85  From September 1942, even before the establish...
# 86  From September 1942, even before the establish...
# 87  During the occupation, Kann organized the Scou...
# 88  Three months after Hitler’s rise to power, in ...
#
# [89 rows x 5 columns]

# %% [markdown]
# ### Making Table 3 Starts

# %%
#Table3
table_3 = pd.DataFrame(columns = ['Story ID','Rescuing Verb', 'Rescuing_phrases-name'])

# %%
# input
# Table1
table_1['sentence'][0]
# check if rescuing verb appear in the sentence. (Lexicon reference - same story ID)
# If there is rescuing verb existed,
# (Also name)
# add this sentence to a new table Table3
# Out:
# 'Ludwig Wörl (1906-1967) spent 11 years of Ludwig Wörl (1906-1967) life as a political prisoner in Nazi concentration camps.  '

# %%
table_1.head()
# Out:
#    storynumber         name                                           sentence
# 0          1.0  Ludwig Wörl  Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 1          1.0  Ludwig Wörl  Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 2          1.0  Ludwig Wörl  Ludwig Wörl (1906-1967) was first arrested by ...
# 3          1.0  Ludwig Wörl  After spending some nine months in a dark dete...
# 4          1.0  Ludwig Wörl  In 1942, Ludwig Wörl (1906-1967) was sent to A...

# %%
list(set(table_2[table_2['Story ID'] == 1]['Rescuing Verb']))
# Out:
# ['influence',
#  'protected',
#  'treatment',
#  'sent',
#  'employed',
#  'put himself at risk',
#  'dedicated',
#  'helped',
#  'protecting',
#  'obtain',
#  'exempted',
#  'saving',
#  'forge']

# %%
table_2
# Out:
#       Story ID        Rescuing Verb  \
# 0          1.0                 sent
# 1          1.0                 sent
# 2          1.0             employed
# 3          1.0               saving
# 4          1.0  put himself at risk
# ...        ...                  ...
# 8922    5257.0         looked after
# 8923    5257.0         looked after
# 8924    5257.0            sheltered
# 8925    5257.0             obtained
# 8926    5257.0               taught
#
#                                         Rescuing Phrase
# 0     his life as a political prisoner in nazi conce...
# 1     to the camp’s joinery and later, as a trained ...
# 2     personnel. appointed as the lagerälteste (the ...
# 3     lagerälteste (the camp elder) of the hospital ...
# 4     barracks, wörl, against the express orders of ...
# ...                                                 ...
# 8922  Helena looked after the children, obtaining "A...
# 8923  Helena looked after the children, obtaining "A...
# 8924  Initially, they were only supposed to stay wit...
# 8925  Helenapresented the fugitives as her brother’s...
# 8926  Helenapresented the fugitives as her brother’s...
#
# [8927 rows x 3 columns]

# %%
# Function to find the rescuer (subject) for each sentence
def find_rescuer(df):
    sentence = df['Rescuing Phrase']
    rescuing_verb = df['Rescuing Verb']
    
    # Skip NaN values
    if pd.isna(sentence):
        return None
    
    # Process sentence with Spacy
    doc = nlp(sentence)
    
    # If the verb is multi-word (like "put himself at risk"), we handle it separately.
    if rescuing_verb in sentence:
        # Find the subject (nsubj) related to the rescuing verb
        for token in doc:
            if rescuing_verb.split()[0] == token.lemma_ or token.text == rescuing_verb.split()[0]:
                # Find the subject (nsubj) linked to the verb
                subject = [child for child in token.children if child.dep_ == "nsubj"]
                if subject:
                    return subject[0].text  # Return the first subject found
    
    return None  # Return None if no subject is found

# %%
table_2.apply(find_rescuer)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-ff4acbd86e1d> in <module>
# ----> 1 table_2.apply(find_rescuer)
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-84-d754705b7529> in find_rescuer(df)
#       1 # Function to find the rescuer (subject) for each sentence
#       2 def find_rescuer(df):
# ----> 3     sentence = df['Rescuing Phrase']
#       4     rescuing_verb = df['Rescuing Verb']
#       5
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
#     387                     raise KeyError(key) from err
# --> 388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#     390
#
# KeyError: 'Rescuing Phrase'

# %%
# Apply the function to the DataFrame
df['Rescuer'] = df.apply(find_rescuer, axis=1)

# %%
table_1
# Out:
#      storynumber           name  \
# 0            1.0    Ludwig Wörl
# 1            1.0    Ludwig Wörl
# 2            1.0    Ludwig Wörl
# 3            1.0    Ludwig Wörl
# 4            1.0    Ludwig Wörl
# ..           ...            ...
# 591         33.0        Strauss
# 592         33.0        Strauss
# 593         33.0  Werner Krumme
# 594         33.0         Vashem
# 595         33.0  Werner Krumme
#
#                                               sentence
# 0    Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 1    Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 2    Ludwig Wörl (1906-1967) was first arrested by ...
# 3    After spending some nine months in a dark dete...
# 4    In 1942, Ludwig Wörl (1906-1967) was sent to A...
# ..                                                 ...
# 591  The Jewish pharmacist Strauss was likewise ass...
# 592  The Jewish pharmacist Strauss was likewise ass...
# 593  Werner Krumme himself was released from Auschw...
# 594  On June 16, 1964, Yad Vashem recognized Werner...
# 595  On June 16, 1964, Yad Vashem recognized Werner...
#
# [596 rows x 3 columns]

# %%
for row in tqdm(table_1.itertuples(), total = table_1.shape[0]):
    # storyid = row.storynumber
    # 본 회차 스토리에서 찾아내야하는 verb 목록 불러오고
    verbs_to_find = list(set(table_2[table_2['Story ID'] == row.storynumber]['Rescuing Verb']))
    # row 한개를 nlp_base에 넣고 verb 추출
    doc = nlp(row.sentence)
    verbs_extracted = [token for token in doc if token.pos_ == 'VERB']
    for verb in verbs_extracted:
        # 존재하는 verb들 중 lexicon verbs 에 있는 verb를 발견하고
        if str(verb) in verbs_to_find:
            # 그 sentence의 사람 이름도 있다면(당연히 있지) 통과
            # 이 부분은 추후에 제거 가능 ( 나혼자 해본것.)
            # for entity in doc.ents:
            #     if entity.label_ == 'PERSON':
            #          print(entity.text)

            new_row = {'Story ID' : row.storynumber, 'Rescuing Verb' : str(verb), 'Rescuing_phrases-name' : row.sentence}
            table_3.loc[len(table_3)] = new_row
# Out:
# 100%|██████████| 596/596 [00:14<00:00, 40.41it/s]

# %%
# Table 3
table_3.drop_duplicates()
# Out:
#      Story ID Rescuing Verb                              Rescuing_phrases-name
# 0         1.0          sent  Ludwig Wörl (1906-1967) was first arrested by ...
# 1         1.0          sent  In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 2         1.0      employed  Appointed as the Lagerälteste (the camp elder)...
# 3         1.0        saving  Appointed as the Lagerälteste (the camp elder)...
# 6         1.0        obtain  Ludwig Wörl (1906-1967) also put Ludwig Wörl (...
# 8         1.0         forge  Ludwig Wörl (1906-1967) would forge selection ...
# 9         1.0    protecting  Here, again, Wörl made Wörl beneficial influen...
# 11        1.0      exempted  Even prisoners with tuberculosis were able to ...
# 12        1.0     protected  Even prisoners with tuberculosis were able to ...
# 13        1.0        helped  At the time of the evacuation of Auschwitz, Wö...
# 14        2.0        helped  Without revealing Johann Pscheidt identity, Jo...
# 16        2.0      employed  Johann Pscheidt also gave the Jewish workers t...
# 17        2.0      provided  Johann Pscheidt also gave the Jewish workers t...
# 20        2.0      arranged  In the beginning of 1943, when the Jews of the...
# 22        2.0          sent  Johann Pscheidt sent each one of The fugitives...
# 23        2.0          sent  As part of the effort to locate Adolf Eichmann...
# 26        3.0      obtained  In time, Professor Czezowski obtained “Aryan” ...
# 29        3.0     sheltered  Professor Czezowski also sheltered a Jewish re...
# 32        4.0        saving  During the occupation, Władysław Kowalski, a q...
# 34        4.0      arranged  Kowalski immediately did as requested, and arr...
# 35        4.0        saving  Kowalski immediately did as requested, and arr...
# 40        4.0        saving  From that day on, Kowalski decided to make sav...
# 41        4.0      arranged  Kowalski let a friend’s house be used as a she...
# 43        4.0      provided  Despite the danger, Kowalski provided the refu...
# 44        4.0        helped  Among the survivors who owed their lives to Ko...
# 54        4.0      arranged  Before the deportation of the remnants of the ...
# 55        4.0        saving  Before the deportation of the remnants of the ...
# 64        7.0        helped  Among the Jews who were helped by Hencel and h...
# 69        8.0          sent  In February 1942, Wolf and Abraham Goldberg – ...
# 73       11.0      arranged  Since immigration to British controlled Palest...
# 75       14.0    discovered  One night in September 1942, Domna Semenyuk we...
# 80       14.0       invited  After some deliberation, Domna Semenyuk invite...
# 83       16.0     persuaded  In 1942, when the deportation from the Węgrow ...
# 85       16.0       married    Władysław married Irena Cymerman after the war.
# 87       19.0     developed  As a consequence of taking up this position, L...
# 89       20.0     developed  Schindler never developed any ideologically mo...
# 90       20.0        obtain  This not only qualified Schindler to obtain lu...
# 92       20.0        obtain  In late 1944, Schindler had managed to obtain ...
# 95       21.0      employed  Vienna-born Julius Madritsch and Titsch employ...
# 97       21.0      arranged  Madritsch and Titsch even arranged for a koshe...
# 99       21.0      provided  Madritsch and Titsch provided sewing materials...
# 100      21.0      employed  This factory, which was also managed by Titsch...
# 101      21.0        helped  Vienna-born Julius Madritsch also helped a num...
# 103      21.0        helped  In these activities, Vienna-born Julius Madrit...
# 105      21.0        helped  Vienna-born Julius Madritsch was again helped ...
# 106      21.0      transfer  Madritsch got permission from the SS to transf...
# 107      21.0        helped  Madritsch and Titsch also helped Jews get out ...
# 109      21.0        helped  In addition to material help, Madritsch and Ti...
# 115      21.0          sent  * (See Germany), and in this way, saved the am...
# 116      22.0       offered  She offered She assistance to Jakub Goldsztajn...
# 117      23.0        helped  Madritsch helped the Jews in the Krakow ghetto...
# 120      23.0      transfer  Again, Vienna-born Oswald Bouska (called in so...
# 122      29.0       helping  Ludwik”) threw Ludwik”) wholeheartedly into wo...
# 124      29.0          sent  As part of Ludwik”) underground activity, Wład...
# 126      29.0        helped  The author, Rachel Auerbach, and Dr. A. Berman...
# 128      30.0          sent  The tract, which was also sent abroad, also co...
# 129      33.0          sent               Krumme was sent to the gas chambers.

# %%
table_3
# Out:
#      Story ID Rescuing Verb                              Rescuing_phrases-name
# 0         1.0          sent  Ludwig Wörl (1906-1967) was first arrested by ...
# 1         1.0          sent  In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 2         1.0      employed  Appointed as the Lagerälteste (the camp elder)...
# 3         1.0        saving  Appointed as the Lagerälteste (the camp elder)...
# 4         1.0      employed  Appointed as the Lagerälteste (the camp elder)...
# ..        ...           ...                                                ...
# 125      29.0          sent  As part of Ludwik”) underground activity, Wład...
# 126      29.0        helped  The author, Rachel Auerbach, and Dr. A. Berman...
# 127      29.0        helped  The author, Rachel Auerbach, and Dr. A. Berman...
# 128      30.0          sent  The tract, which was also sent abroad, also co...
# 129      33.0          sent               Krumme was sent to the gas chambers.
#
# [130 rows x 3 columns]

# %%
table_3.iloc[9]
# Out:
# Story ID                                                               1.0
# Rescuing Verb                                                   protecting
# Rescuing_phrases-name    Here, again, Wörl made Wörl beneficial influen...
# Name: 9, dtype: object

# %%
# Table_4 (Merge table_2 and table_3)
# table_4: Complete Lexicon Structure Example
table_4 = pd.merge(table_2, table_3, how = 'left', on = ['Story ID','Rescuing Verb'])

# %%
table_4
# Out:
#       Story ID Rescuing Verb  \
# 0          1.0          sent
# 1          1.0          sent
# 2          1.0          sent
# 3          1.0          sent
# 4          1.0      employed
# ...        ...           ...
# 9121    5257.0  looked after
# 9122    5257.0  looked after
# 9123    5257.0     sheltered
# 9124    5257.0      obtained
# 9125    5257.0        taught
#
#                                         Rescuing Phrase  \
# 0     his life as a political prisoner in nazi conce...
# 1     his life as a political prisoner in nazi conce...
# 2     to the camp’s joinery and later, as a trained ...
# 3     to the camp’s joinery and later, as a trained ...
# 4     personnel. appointed as the lagerälteste (the ...
# ...                                                 ...
# 9121  Helena looked after the children, obtaining "A...
# 9122  Helena looked after the children, obtaining "A...
# 9123  Initially, they were only supposed to stay wit...
# 9124  Helenapresented the fugitives as her brother’s...
# 9125  Helenapresented the fugitives as her brother’s...
#
#                                   Rescuing_phrases-name
# 0     Ludwig Wörl (1906-1967) was first arrested by ...
# 1     In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 2     Ludwig Wörl (1906-1967) was first arrested by ...
# 3     In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 4     Appointed as the Lagerälteste (the camp elder)...
# ...                                                 ...
# 9121                                                NaN
# 9122                                                NaN
# 9123                                                NaN
# 9124                                                NaN
# 9125                                                NaN
#
# [9126 rows x 4 columns]

# %%
# drop duplicated rows
table_4.drop_duplicates(inplace = True)

# %%
table_4
# Out:
#       Story ID Rescuing Verb  \
# 0          1.0          sent
# 1          1.0          sent
# 2          1.0          sent
# 3          1.0          sent
# 4          1.0      employed
# ...        ...           ...
# 9120    4481.0    recognized
# 9121    5257.0  looked after
# 9123    5257.0     sheltered
# 9124    5257.0      obtained
# 9125    5257.0        taught
#
#                                         Rescuing Phrase  \
# 0     his life as a political prisoner in nazi conce...
# 1     his life as a political prisoner in nazi conce...
# 2     to the camp’s joinery and later, as a trained ...
# 3     to the camp’s joinery and later, as a trained ...
# 4     personnel. appointed as the lagerälteste (the ...
# ...                                                 ...
# 9120  On January 17, 1990, Yad Vashem recognized Józ...
# 9121  Helena looked after the children, obtaining "A...
# 9123  Initially, they were only supposed to stay wit...
# 9124  Helenapresented the fugitives as her brother’s...
# 9125  Helenapresented the fugitives as her brother’s...
#
#                                   Rescuing_phrases-name
# 0     Ludwig Wörl (1906-1967) was first arrested by ...
# 1     In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 2     Ludwig Wörl (1906-1967) was first arrested by ...
# 3     In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 4     Appointed as the Lagerälteste (the camp elder)...
# ...                                                 ...
# 9120                                                NaN
# 9121                                                NaN
# 9123                                                NaN
# 9124                                                NaN
# 9125                                                NaN
#
# [8974 rows x 4 columns]

# %%
table_4.to_csv('./drafts/table_4.xlsx', index = False)

# %% [markdown]
# ### 1.2.1.2 Step 2:“Rescuers Names filtering” - Step-by-Step Breakdown

# %%
table_4 = pd.read_csv('./drafts/table_4.xlsx')

# %%
table_4
# Out:
#       Story ID Rescuing Verb  \
# 0          1.0          sent
# 1          1.0          sent
# 2          1.0          sent
# 3          1.0          sent
# 4          1.0      employed
# ...        ...           ...
# 9120    4481.0    recognized
# 9121    5257.0  looked after
# 9123    5257.0     sheltered
# 9124    5257.0      obtained
# 9125    5257.0        taught
#
#                                         Rescuing Phrase  \
# 0     his life as a political prisoner in nazi conce...
# 1     his life as a political prisoner in nazi conce...
# 2     to the camp’s joinery and later, as a trained ...
# 3     to the camp’s joinery and later, as a trained ...
# 4     personnel. appointed as the lagerälteste (the ...
# ...                                                 ...
# 9120  On January 17, 1990, Yad Vashem recognized Józ...
# 9121  Helena looked after the children, obtaining "A...
# 9123  Initially, they were only supposed to stay wit...
# 9124  Helenapresented the fugitives as her brother’s...
# 9125  Helenapresented the fugitives as her brother’s...
#
#                                   Rescuing_phrases-name
# 0     Ludwig Wörl (1906-1967) was first arrested by ...
# 1     In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 2     Ludwig Wörl (1906-1967) was first arrested by ...
# 3     In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 4     Appointed as the Lagerälteste (the camp elder)...
# ...                                                 ...
# 9120                                                NaN
# 9121                                                NaN
# 9123                                                NaN
# 9124                                                NaN
# 9125                                                NaN
#
# [8974 rows x 4 columns]

# %%
# Function to find the full name of the rescuer, and split it into first name and last name
def extract_name_info(row):
    sentence = row['Rescuing_phrases-name']  # Adjusted column name
    rescuing_verb = row['Rescuing Verb']    # Adjusted column name
    
    # Skip NaN values
    if pd.isna(sentence):
        return pd.Series([None, None, None])  # Return None for full name, first name, and last name
    
    # Process sentence with Spacy
    doc = nlp(sentence)
    
    # Find the full name of the rescuer using NER
    full_name = None
    for ent in doc.ents:
        if ent.label_ == "PERSON":
            full_name = ent.text  # Get the first PERSON entity (assuming it's the rescuer)
            break
    
    if not full_name:
        return pd.Series([None, None, None])  # Return None if no PERSON entity is found
    
    # Split the full name into first and last name
    name_parts = full_name.split()
    if len(name_parts) > 1:
        last_name = name_parts[-1]
        first_name = " ".join(name_parts[:-1])
    else:
        first_name = full_name
        last_name = None  # If no last name, leave it as None
    
    return pd.Series([full_name, first_name, last_name])

# %%
sample_table_4 = table_4[:40]

# %%
sample_table_4
# Out:
#     Story ID        Rescuing Verb  \
# 0        1.0                 sent
# 1        1.0                 sent
# 2        1.0                 sent
# 3        1.0                 sent
# 4        1.0             employed
# 6        1.0               saving
# 8        1.0  put himself at risk
# 9        1.0               obtain
# 11       1.0            treatment
# 12       1.0                forge
# 13       1.0            influence
# 14       1.0           protecting
# 16       1.0             exempted
# 17       1.0            protected
# 18       1.0               helped
# 19       1.0            dedicated
# 20       2.0                 sent
# 21       2.0                 sent
# 24       2.0                 sent
# 25       2.0                 sent
# 28       2.0             arranged
# 30       2.0               rescue
# 31       2.0             provided
# 33       2.0             employed
# 35       2.0               helped
# 37       3.0             smuggled
# 38       3.0            sheltered
# 41       3.0             obtained
# 44       4.0             arranged
# 47       4.0             arranged
# 49       4.0             arranged
# 54       4.0             arranged
# 57       4.0             arranged
# 59       4.0             arranged
# 64       4.0             arranged
# 67       4.0             arranged
# 69       4.0             arranged
# 74       4.0              shelter
# 75       4.0              shelter
# 76       4.0               rescue
#
#                                       Rescuing Phrase  \
# 0   his life as a political prisoner in nazi conce...
# 1   his life as a political prisoner in nazi conce...
# 2   to the camp’s joinery and later, as a trained ...
# 3   to the camp’s joinery and later, as a trained ...
# 4   personnel. appointed as the lagerälteste (the ...
# 6   lagerälteste (the camp elder) of the hospital ...
# 8   barracks, wörl, against the express orders of ...
# 9   the ss, employed jewish doctors, thus saving t...
# 11  himself at risk in order to obtain at least a ...
# 12  obtain at least a minimum of the required medi...
# 13  german descent and seniority, put in charge of...
# 14  and seniority, put in charge of güntergrube, a...
# 16  that they get their due share of food and clot...
# 17  of food and clothing. even prisoners with tube...
# 18  them by various subterfuges from the inspectio...
# 19  the infamous death marches. after the war wörl...
# 20  on the black market. the fugitives came out of...
# 21  on the black market. the fugitives came out of...
# 24  to help in the struggle against the nazis. as ...
# 25  to help in the struggle against the nazis. as ...
# 28  with the zionist underground. in the beginning...
# 30  he managed, which was situated only a few mete...
# 31  with food and money. he also gave the jewish w...
# 33  identity, he helped poor jews in the city with...
# 35  german. at the beginning of the 1930s, pscheid...
# 37  The Czeżowskis smuggled food into the ghetto f...
# 38  The Czeżowskis sheltered eight members of the ...
# 41  Professor Czezowski obtained “Aryan” documents...
# 44  being persecuted. i haven’t eaten for three da...
# 47  being persecuted. i haven’t eaten for three da...
# 49  being persecuted. i haven’t eaten for three da...
# 54  saving jews his life’s mission. he let his hou...
# 57  saving jews his life’s mission. he let his hou...
# 59  saving jews his life’s mission. he let his hou...
# 64  ghetto and, at great personal risk, smuggled o...
# 67  ghetto and, at great personal risk, smuggled o...
# 69  ghetto and, at great personal risk, smuggled o...
# 74  persecuted. i haven’t eaten for three days. pl...
# 75  on, kowalski decided to make saving jews his l...
# 76  a qualified engineer and colonel in the polish...
#
#                                 Rescuing_phrases-name
# 0   Ludwig Wörl (1906-1967) was first arrested by ...
# 1   In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 2   Ludwig Wörl (1906-1967) was first arrested by ...
# 3   In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 4   Appointed as the Lagerälteste (the camp elder)...
# 6   Appointed as the Lagerälteste (the camp elder)...
# 8                                                 NaN
# 9   Ludwig Wörl (1906-1967) also put Ludwig Wörl (...
# 11                                                NaN
# 12  Ludwig Wörl (1906-1967) would forge selection ...
# 13                                                NaN
# 14  Here, again, Wörl made Wörl beneficial influen...
# 16  Even prisoners with tuberculosis were able to ...
# 17  Even prisoners with tuberculosis were able to ...
# 18  At the time of the evacuation of Auschwitz, Wö...
# 19                                                NaN
# 20  Johann Pscheidt sent each one of The fugitives...
# 21  As part of the effort to locate Adolf Eichmann...
# 24  Johann Pscheidt sent each one of The fugitives...
# 25  As part of the effort to locate Adolf Eichmann...
# 28  In the beginning of 1943, when the Jews of the...
# 30                                                NaN
# 31  Johann Pscheidt also gave the Jewish workers t...
# 33  Johann Pscheidt also gave the Jewish workers t...
# 35  Without revealing Johann Pscheidt identity, Jo...
# 37                                                NaN
# 38  Professor Czezowski also sheltered a Jewish re...
# 41  In time, Professor Czezowski obtained “Aryan” ...
# 44  Kowalski immediately did as requested, and arr...
# 47  Kowalski let a friend’s house be used as a she...
# 49  Before the deportation of the remnants of the ...
# 54  Kowalski immediately did as requested, and arr...
# 57  Kowalski let a friend’s house be used as a she...
# 59  Before the deportation of the remnants of the ...
# 64  Kowalski immediately did as requested, and arr...
# 67  Kowalski let a friend’s house be used as a she...
# 69  Before the deportation of the remnants of the ...
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN

# %%
# Apply the function to the DataFrame and store the results in separate columns
sample_table_4[['Full Name', 'First Name', 'Last Name']] = sample_table_4.apply(extract_name_info, axis=1)
# Out:
# /Users/minjoo/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
sample_table_4
# Out:
#     Story ID        Rescuing Verb  \
# 0        1.0                 sent
# 1        1.0                 sent
# 2        1.0                 sent
# 3        1.0                 sent
# 4        1.0             employed
# 6        1.0               saving
# 8        1.0  put himself at risk
# 9        1.0               obtain
# 11       1.0            treatment
# 12       1.0                forge
# 13       1.0            influence
# 14       1.0           protecting
# 16       1.0             exempted
# 17       1.0            protected
# 18       1.0               helped
# 19       1.0            dedicated
# 20       2.0                 sent
# 21       2.0                 sent
# 24       2.0                 sent
# 25       2.0                 sent
# 28       2.0             arranged
# 30       2.0               rescue
# 31       2.0             provided
# 33       2.0             employed
# 35       2.0               helped
# 37       3.0             smuggled
# 38       3.0            sheltered
# 41       3.0             obtained
# 44       4.0             arranged
# 47       4.0             arranged
# 49       4.0             arranged
# 54       4.0             arranged
# 57       4.0             arranged
# 59       4.0             arranged
# 64       4.0             arranged
# 67       4.0             arranged
# 69       4.0             arranged
# 74       4.0              shelter
# 75       4.0              shelter
# 76       4.0               rescue
#
#                                       Rescuing Phrase  \
# 0   his life as a political prisoner in nazi conce...
# 1   his life as a political prisoner in nazi conce...
# 2   to the camp’s joinery and later, as a trained ...
# 3   to the camp’s joinery and later, as a trained ...
# 4   personnel. appointed as the lagerälteste (the ...
# 6   lagerälteste (the camp elder) of the hospital ...
# 8   barracks, wörl, against the express orders of ...
# 9   the ss, employed jewish doctors, thus saving t...
# 11  himself at risk in order to obtain at least a ...
# 12  obtain at least a minimum of the required medi...
# 13  german descent and seniority, put in charge of...
# 14  and seniority, put in charge of güntergrube, a...
# 16  that they get their due share of food and clot...
# 17  of food and clothing. even prisoners with tube...
# 18  them by various subterfuges from the inspectio...
# 19  the infamous death marches. after the war wörl...
# 20  on the black market. the fugitives came out of...
# 21  on the black market. the fugitives came out of...
# 24  to help in the struggle against the nazis. as ...
# 25  to help in the struggle against the nazis. as ...
# 28  with the zionist underground. in the beginning...
# 30  he managed, which was situated only a few mete...
# 31  with food and money. he also gave the jewish w...
# 33  identity, he helped poor jews in the city with...
# 35  german. at the beginning of the 1930s, pscheid...
# 37  The Czeżowskis smuggled food into the ghetto f...
# 38  The Czeżowskis sheltered eight members of the ...
# 41  Professor Czezowski obtained “Aryan” documents...
# 44  being persecuted. i haven’t eaten for three da...
# 47  being persecuted. i haven’t eaten for three da...
# 49  being persecuted. i haven’t eaten for three da...
# 54  saving jews his life’s mission. he let his hou...
# 57  saving jews his life’s mission. he let his hou...
# 59  saving jews his life’s mission. he let his hou...
# 64  ghetto and, at great personal risk, smuggled o...
# 67  ghetto and, at great personal risk, smuggled o...
# 69  ghetto and, at great personal risk, smuggled o...
# 74  persecuted. i haven’t eaten for three days. pl...
# 75  on, kowalski decided to make saving jews his l...
# 76  a qualified engineer and colonel in the polish...
#
#                                 Rescuing_phrases-name        Full Name  \
# 0   Ludwig Wörl (1906-1967) was first arrested by ...      Ludwig Wörl
# 1   In 1942, Ludwig Wörl (1906-1967) was sent to A...      Ludwig Wörl
# 2   Ludwig Wörl (1906-1967) was first arrested by ...      Ludwig Wörl
# 3   In 1942, Ludwig Wörl (1906-1967) was sent to A...      Ludwig Wörl
# 4   Appointed as the Lagerälteste (the camp elder)...     Lagerälteste
# 6   Appointed as the Lagerälteste (the camp elder)...     Lagerälteste
# 8                                                 NaN             None
# 9   Ludwig Wörl (1906-1967) also put Ludwig Wörl (...      Ludwig Wörl
# 11                                                NaN             None
# 12  Ludwig Wörl (1906-1967) would forge selection ...      Ludwig Wörl
# 13                                                NaN             None
# 14  Here, again, Wörl made Wörl beneficial influen...             Wörl
# 16  Even prisoners with tuberculosis were able to ...             None
# 17  Even prisoners with tuberculosis were able to ...             None
# 18  At the time of the evacuation of Auschwitz, Wö...             Wörl
# 19                                                NaN             None
# 20  Johann Pscheidt sent each one of The fugitives...  Johann Pscheidt
# 21  As part of the effort to locate Adolf Eichmann...   Adolf Eichmann
# 24  Johann Pscheidt sent each one of The fugitives...  Johann Pscheidt
# 25  As part of the effort to locate Adolf Eichmann...   Adolf Eichmann
# 28  In the beginning of 1943, when the Jews of the...  Johann Pscheidt
# 30                                                NaN             None
# 31  Johann Pscheidt also gave the Jewish workers t...  Johann Pscheidt
# 33  Johann Pscheidt also gave the Jewish workers t...  Johann Pscheidt
# 35  Without revealing Johann Pscheidt identity, Jo...  Johann Pscheidt
# 37                                                NaN             None
# 38  Professor Czezowski also sheltered a Jewish re...        Czezowski
# 41  In time, Professor Czezowski obtained “Aryan” ...        Czezowski
# 44  Kowalski immediately did as requested, and arr...         Kowalski
# 47  Kowalski let a friend’s house be used as a she...         Kowalski
# 49  Before the deportation of the remnants of the ...         Kowalski
# 54  Kowalski immediately did as requested, and arr...         Kowalski
# 57  Kowalski let a friend’s house be used as a she...         Kowalski
# 59  Before the deportation of the remnants of the ...         Kowalski
# 64  Kowalski immediately did as requested, and arr...         Kowalski
# 67  Kowalski let a friend’s house be used as a she...         Kowalski
# 69  Before the deportation of the remnants of the ...         Kowalski
# 74                                                NaN             None
# 75                                                NaN             None
# 76                                                NaN             None
#
#       First Name Last Name
# 0         Ludwig      Wörl
# 1         Ludwig      Wörl
# 2         Ludwig      Wörl
# 3         Ludwig      Wörl
# 4   Lagerälteste      None
# 6   Lagerälteste      None
# 8           None      None
# 9         Ludwig      Wörl
# 11          None      None
# 12        Ludwig      Wörl
# 13          None      None
# 14          Wörl      None
# 16          None      None
# 17          None      None
# 18          Wörl      None
# 19          None      None
# 20        Johann  Pscheidt
# 21         Adolf  Eichmann
# 24        Johann  Pscheidt
# 25         Adolf  Eichmann
# 28        Johann  Pscheidt
# 30          None      None
# 31        Johann  Pscheidt
# 33        Johann  Pscheidt
# 35        Johann  Pscheidt
# 37          None      None
# 38     Czezowski      None
# 41     Czezowski      None
# 44      Kowalski      None
# 47      Kowalski      None
# 49      Kowalski      None
# 54      Kowalski      None
# 57      Kowalski      None
# 59      Kowalski      None
# 64      Kowalski      None
# 67      Kowalski      None
# 69      Kowalski      None
# 74          None      None
# 75          None      None
# 76          None      None

# %%
table_5 = sample_table_4[['Story ID','Full Name', 'Last Name', 'First Name', 'Rescuing_phrases-name']]

# %%
table_5
# Out:
#     Story ID        Full Name Last Name    First Name  \
# 0        1.0      Ludwig Wörl      Wörl        Ludwig
# 1        1.0      Ludwig Wörl      Wörl        Ludwig
# 2        1.0      Ludwig Wörl      Wörl        Ludwig
# 3        1.0      Ludwig Wörl      Wörl        Ludwig
# 4        1.0     Lagerälteste      None  Lagerälteste
# 6        1.0     Lagerälteste      None  Lagerälteste
# 8        1.0             None      None          None
# 9        1.0      Ludwig Wörl      Wörl        Ludwig
# 11       1.0             None      None          None
# 12       1.0      Ludwig Wörl      Wörl        Ludwig
# 13       1.0             None      None          None
# 14       1.0             Wörl      None          Wörl
# 16       1.0             None      None          None
# 17       1.0             None      None          None
# 18       1.0             Wörl      None          Wörl
# 19       1.0             None      None          None
# 20       2.0  Johann Pscheidt  Pscheidt        Johann
# 21       2.0   Adolf Eichmann  Eichmann         Adolf
# 24       2.0  Johann Pscheidt  Pscheidt        Johann
# 25       2.0   Adolf Eichmann  Eichmann         Adolf
# 28       2.0  Johann Pscheidt  Pscheidt        Johann
# 30       2.0             None      None          None
# 31       2.0  Johann Pscheidt  Pscheidt        Johann
# 33       2.0  Johann Pscheidt  Pscheidt        Johann
# 35       2.0  Johann Pscheidt  Pscheidt        Johann
# 37       3.0             None      None          None
# 38       3.0        Czezowski      None     Czezowski
# 41       3.0        Czezowski      None     Czezowski
# 44       4.0         Kowalski      None      Kowalski
# 47       4.0         Kowalski      None      Kowalski
# 49       4.0         Kowalski      None      Kowalski
# 54       4.0         Kowalski      None      Kowalski
# 57       4.0         Kowalski      None      Kowalski
# 59       4.0         Kowalski      None      Kowalski
# 64       4.0         Kowalski      None      Kowalski
# 67       4.0         Kowalski      None      Kowalski
# 69       4.0         Kowalski      None      Kowalski
# 74       4.0             None      None          None
# 75       4.0             None      None          None
# 76       4.0             None      None          None
#
#                                 Rescuing_phrases-name
# 0   Ludwig Wörl (1906-1967) was first arrested by ...
# 1   In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 2   Ludwig Wörl (1906-1967) was first arrested by ...
# 3   In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 4   Appointed as the Lagerälteste (the camp elder)...
# 6   Appointed as the Lagerälteste (the camp elder)...
# 8                                                 NaN
# 9   Ludwig Wörl (1906-1967) also put Ludwig Wörl (...
# 11                                                NaN
# 12  Ludwig Wörl (1906-1967) would forge selection ...
# 13                                                NaN
# 14  Here, again, Wörl made Wörl beneficial influen...
# 16  Even prisoners with tuberculosis were able to ...
# 17  Even prisoners with tuberculosis were able to ...
# 18  At the time of the evacuation of Auschwitz, Wö...
# 19                                                NaN
# 20  Johann Pscheidt sent each one of The fugitives...
# 21  As part of the effort to locate Adolf Eichmann...
# 24  Johann Pscheidt sent each one of The fugitives...
# 25  As part of the effort to locate Adolf Eichmann...
# 28  In the beginning of 1943, when the Jews of the...
# 30                                                NaN
# 31  Johann Pscheidt also gave the Jewish workers t...
# 33  Johann Pscheidt also gave the Jewish workers t...
# 35  Without revealing Johann Pscheidt identity, Jo...
# 37                                                NaN
# 38  Professor Czezowski also sheltered a Jewish re...
# 41  In time, Professor Czezowski obtained “Aryan” ...
# 44  Kowalski immediately did as requested, and arr...
# 47  Kowalski let a friend’s house be used as a she...
# 49  Before the deportation of the remnants of the ...
# 54  Kowalski immediately did as requested, and arr...
# 57  Kowalski let a friend’s house be used as a she...
# 59  Before the deportation of the remnants of the ...
# 64  Kowalski immediately did as requested, and arr...
# 67  Kowalski let a friend’s house be used as a she...
# 69  Before the deportation of the remnants of the ...
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN

# %%
table_5 = sample_table_4[['Story ID','Full Name', 'Last Name', 'First Name', 'Resuing_phrases-name']]
# Out:
#     Story ID       Full Name Last Name    First Name  \
# 0        1.0            None      None          None
# 1        1.0            None      None          None
# 2        1.0    Lagerälteste      None  Lagerälteste
# 3        1.0    Lagerälteste      None  Lagerälteste
# 4        1.0    Lagerälteste      None  Lagerälteste
# 5        1.0    Lagerälteste      None  Lagerälteste
# 6        1.0            None      None          None
# 7        1.0            None      None          None
# 8        1.0            None      None          None
# 9        1.0            None      None          None
# 10       1.0            None      None          None
# 11       1.0           Kapos      None         Kapos
# 12       1.0            Wörl      None          Wörl
# 13       1.0            Wörl      None          Wörl
# 14       1.0            None      None          None
# 15       1.0            Wörl      None          Wörl
# 16       2.0            None      None          None
# 17       2.0  Adolf Eichmann  Eichmann         Adolf
# 18       2.0  Adolf Eichmann  Eichmann         Adolf
# 19       2.0            None      None          None
#
#                                  Resuing_phrases-name
# 0                                                 NaN
# 1                                                 NaN
# 2   Appointed as the Lagerälteste (the camp elder)...
# 3   Appointed as the Lagerälteste (the camp elder)...
# 4   Appointed as the Lagerälteste (the camp elder)...
# 5   Appointed as the Lagerälteste (the camp elder)...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Here, again, he made his beneficial influence ...
# 12  Even prisoners with tuberculosis were able to ...
# 13  Even prisoners with tuberculosis were able to ...
# 14                                                NaN
# 15  After the war Wörl, who became chairman of the...
# 16  Pscheidt sent each one of them off with gifts ...
# 17  As part of the effort to locate Adolf Eichmann...
# 18  As part of the effort to locate Adolf Eichmann...
# 19  Pscheidt sent each one of them off with gifts ...

# %%
table_5.to_csv('3415_SPACY_All_Rescuers.xlsx', index = False)

# %% [markdown]
# ### Rescuing DATE

# %%
# Function to find the full name of the rescuer, first name, last name, and the rescued date
def extract_name_and_date(row):
    sentence = row['Rescuing_phrases-name']  # Adjusted column name
    rescuing_verb = row['Rescuing Verb']    # Adjusted column name
    
    # Skip NaN values
    if pd.isna(sentence):
        return pd.Series([None, None, None, None])  # Return None for all if sentence is NaN
    
    # Process sentence with Spacy
    doc = nlp(sentence)
    
    # Extract full name (PERSON) and rescued date (DATE)
    full_name = None
    rescued_date = None
    for ent in doc.ents:
        if ent.label_ == "PERSON" and full_name is None:  # Get the first PERSON entity
            full_name = ent.text
        if ent.label_ == "DATE" and rescued_date is None:  # Get the first DATE entity
            rescued_date = ent.text

    if not full_name:
        return pd.Series([None, None, None, rescued_date])  # Return None for names if no PERSON found
    
    # Split the full name into first name and last name
    name_parts = full_name.split()
    if len(name_parts) > 1:
        last_name = name_parts[-1]
        first_name = " ".join(name_parts[:-1])
    else:
        first_name = full_name
        last_name = None  # If no last name, leave it as None
    
    return pd.Series([full_name, first_name, last_name, rescued_date])

# %%
# Apply the function to the DataFrame and store the results in separate columns
sample_table_4[['Full Name', 'First Name', 'Last Name', 'Rescued Date']] = sample_table_4.apply(extract_name_and_date, axis=1)

# Print the resulting DataFrame
print(sample_table_4)
# Out:
#     Story ID        Rescuing Verb  \
# 0        1.0                 sent
# 1        1.0                 sent
# 2        1.0                 sent
# 3        1.0                 sent
# 4        1.0             employed
# 6        1.0               saving
# 8        1.0  put himself at risk
# 9        1.0               obtain
# 11       1.0            treatment
# 12       1.0                forge
# 13       1.0            influence
# 14       1.0           protecting
# 16       1.0             exempted
# 17       1.0            protected
# 18       1.0               helped
# 19       1.0            dedicated
# 20       2.0                 sent
# 21       2.0                 sent
# 24       2.0                 sent
# 25       2.0                 sent
# 28       2.0             arranged
# 30       2.0               rescue
# 31       2.0             provided
# 33       2.0             employed
# 35       2.0               helped
# 37       3.0             smuggled
# 38       3.0            sheltered
# 41       3.0             obtained
# 44       4.0             arranged
# 47       4.0             arranged
# 49       4.0             arranged
# 54       4.0             arranged
# 57       4.0             arranged
# 59       4.0             arranged
# 64       4.0             arranged
# 67       4.0             arranged
# 69       4.0             arranged
# 74       4.0              shelter
# 75       4.0              shelter
# 76       4.0               rescue
#
#                                       Rescuing Phrase  \
# 0   his life as a political prisoner in nazi conce...
# 1   his life as a political prisoner in nazi conce...
# 2   to the camp’s joinery and later, as a trained ...
# 3   to the camp’s joinery and later, as a trained ...
# 4   personnel. appointed as the lagerälteste (the ...
# 6   lagerälteste (the camp elder) of the hospital ...
# 8   barracks, wörl, against the express orders of ...
# 9   the ss, employed jewish doctors, thus saving t...
# 11  himself at risk in order to obtain at least a ...
# 12  obtain at least a minimum of the required medi...
# 13  german descent and seniority, put in charge of...
# 14  and seniority, put in charge of güntergrube, a...
# 16  that they get their due share of food and clot...
# 17  of food and clothing. even prisoners with tube...
# 18  them by various subterfuges from the inspectio...
# 19  the infamous death marches. after the war wörl...
# 20  on the black market. the fugitives came out of...
# 21  on the black market. the fugitives came out of...
# 24  to help in the struggle against the nazis. as ...
# 25  to help in the struggle against the nazis. as ...
# 28  with the zionist underground. in the beginning...
# 30  he managed, which was situated only a few mete...
# 31  with food and money. he also gave the jewish w...
# 33  identity, he helped poor jews in the city with...
# 35  german. at the beginning of the 1930s, pscheid...
# 37  The Czeżowskis smuggled food into the ghetto f...
# 38  The Czeżowskis sheltered eight members of the ...
# 41  Professor Czezowski obtained “Aryan” documents...
# 44  being persecuted. i haven’t eaten for three da...
# 47  being persecuted. i haven’t eaten for three da...
# 49  being persecuted. i haven’t eaten for three da...
# 54  saving jews his life’s mission. he let his hou...
# 57  saving jews his life’s mission. he let his hou...
# 59  saving jews his life’s mission. he let his hou...
# 64  ghetto and, at great personal risk, smuggled o...
# 67  ghetto and, at great personal risk, smuggled o...
# 69  ghetto and, at great personal risk, smuggled o...
# 74  persecuted. i haven’t eaten for three days. pl...
# 75  on, kowalski decided to make saving jews his l...
# 76  a qualified engineer and colonel in the polish...
#
#                                 Rescuing_phrases-name        Full Name  \
# 0   Ludwig Wörl (1906-1967) was first arrested by ...      Ludwig Wörl
# 1   In 1942, Ludwig Wörl (1906-1967) was sent to A...      Ludwig Wörl
# 2   Ludwig Wörl (1906-1967) was first arrested by ...      Ludwig Wörl
# 3   In 1942, Ludwig Wörl (1906-1967) was sent to A...      Ludwig Wörl
# 4   Appointed as the Lagerälteste (the camp elder)...     Lagerälteste
# 6   Appointed as the Lagerälteste (the camp elder)...     Lagerälteste
# 8                                                 NaN             None
# 9   Ludwig Wörl (1906-1967) also put Ludwig Wörl (...      Ludwig Wörl
# 11                                                NaN             None
# 12  Ludwig Wörl (1906-1967) would forge selection ...      Ludwig Wörl
# 13                                                NaN             None
# 14  Here, again, Wörl made Wörl beneficial influen...             Wörl
# 16  Even prisoners with tuberculosis were able to ...             None
# 17  Even prisoners with tuberculosis were able to ...             None
# 18  At the time of the evacuation of Auschwitz, Wö...             Wörl
# 19                                                NaN             None
# 20  Johann Pscheidt sent each one of The fugitives...  Johann Pscheidt
# 21  As part of the effort to locate Adolf Eichmann...   Adolf Eichmann
# 24  Johann Pscheidt sent each one of The fugitives...  Johann Pscheidt
# 25  As part of the effort to locate Adolf Eichmann...   Adolf Eichmann
# 28  In the beginning of 1943, when the Jews of the...  Johann Pscheidt
# 30                                                NaN             None
# 31  Johann Pscheidt also gave the Jewish workers t...  Johann Pscheidt
# 33  Johann Pscheidt also gave the Jewish workers t...  Johann Pscheidt
# 35  Without revealing Johann Pscheidt identity, Jo...  Johann Pscheidt
# 37                                                NaN             None
# 38  Professor Czezowski also sheltered a Jewish re...        Czezowski
# 41  In time, Professor Czezowski obtained “Aryan” ...        Czezowski
# 44  Kowalski immediately did as requested, and arr...         Kowalski
# 47  Kowalski let a friend’s house be used as a she...         Kowalski
# 49  Before the deportation of the remnants of the ...         Kowalski
# 54  Kowalski immediately did as requested, and arr...         Kowalski
# 57  Kowalski let a friend’s house be used as a she...         Kowalski
# 59  Before the deportation of the remnants of the ...         Kowalski
# 64  Kowalski immediately did as requested, and arr...         Kowalski
# 67  Kowalski let a friend’s house be used as a she...         Kowalski
# 69  Before the deportation of the remnants of the ...         Kowalski
# 74                                                NaN             None
# 75                                                NaN             None
# 76                                                NaN             None
#
#       First Name Last Name           Rescued Date
# 0         Ludwig      Wörl              1906-1967
# 1         Ludwig      Wörl                   1942
# 2         Ludwig      Wörl              1906-1967
# 3         Ludwig      Wörl                   1942
# 4   Lagerälteste      None                   None
# 6   Lagerälteste      None                   None
# 8           None      None                   None
# 9         Ludwig      Wörl              1906-1967
# 11          None      None                   None
# 12        Ludwig      Wörl              1906-1967
# 13          None      None                   None
# 14          Wörl      None                   None
# 16          None      None                   None
# 17          None      None                   None
# 18          Wörl      None                   None
# 19          None      None                   None
# 20        Johann  Pscheidt                   None
# 21         Adolf  Eichmann                   None
# 24        Johann  Pscheidt                   None
# 25         Adolf  Eichmann                   None
# 28        Johann  Pscheidt  the beginning of 1943
# 30          None      None                   None
# 31        Johann  Pscheidt                   None
# 33        Johann  Pscheidt                   None
# 35        Johann  Pscheidt                   None
# 37          None      None                   None
# 38     Czezowski      None              July 1944
# 41     Czezowski      None                   None
# 44      Kowalski      None                   None
# 47      Kowalski      None                   None
# 49      Kowalski      None                   None
# 54      Kowalski      None                   None
# 57      Kowalski      None                   None
# 59      Kowalski      None                   None
# 64      Kowalski      None                   None
# 67      Kowalski      None                   None
# 69      Kowalski      None                   None
# 74          None      None                   None
# 75          None      None                   None
# 76          None      None                   None
# /Users/minjoo/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
sample_table_4
# Out:
#     Story ID        Rescuing Verb  \
# 0        1.0                 sent
# 1        1.0                 sent
# 2        1.0                 sent
# 3        1.0                 sent
# 4        1.0             employed
# 6        1.0               saving
# 8        1.0  put himself at risk
# 9        1.0               obtain
# 11       1.0            treatment
# 12       1.0                forge
# 13       1.0            influence
# 14       1.0           protecting
# 16       1.0             exempted
# 17       1.0            protected
# 18       1.0               helped
# 19       1.0            dedicated
# 20       2.0                 sent
# 21       2.0                 sent
# 24       2.0                 sent
# 25       2.0                 sent
# 28       2.0             arranged
# 30       2.0               rescue
# 31       2.0             provided
# 33       2.0             employed
# 35       2.0               helped
# 37       3.0             smuggled
# 38       3.0            sheltered
# 41       3.0             obtained
# 44       4.0             arranged
# 47       4.0             arranged
# 49       4.0             arranged
# 54       4.0             arranged
# 57       4.0             arranged
# 59       4.0             arranged
# 64       4.0             arranged
# 67       4.0             arranged
# 69       4.0             arranged
# 74       4.0              shelter
# 75       4.0              shelter
# 76       4.0               rescue
#
#                                       Rescuing Phrase  \
# 0   his life as a political prisoner in nazi conce...
# 1   his life as a political prisoner in nazi conce...
# 2   to the camp’s joinery and later, as a trained ...
# 3   to the camp’s joinery and later, as a trained ...
# 4   personnel. appointed as the lagerälteste (the ...
# 6   lagerälteste (the camp elder) of the hospital ...
# 8   barracks, wörl, against the express orders of ...
# 9   the ss, employed jewish doctors, thus saving t...
# 11  himself at risk in order to obtain at least a ...
# 12  obtain at least a minimum of the required medi...
# 13  german descent and seniority, put in charge of...
# 14  and seniority, put in charge of güntergrube, a...
# 16  that they get their due share of food and clot...
# 17  of food and clothing. even prisoners with tube...
# 18  them by various subterfuges from the inspectio...
# 19  the infamous death marches. after the war wörl...
# 20  on the black market. the fugitives came out of...
# 21  on the black market. the fugitives came out of...
# 24  to help in the struggle against the nazis. as ...
# 25  to help in the struggle against the nazis. as ...
# 28  with the zionist underground. in the beginning...
# 30  he managed, which was situated only a few mete...
# 31  with food and money. he also gave the jewish w...
# 33  identity, he helped poor jews in the city with...
# 35  german. at the beginning of the 1930s, pscheid...
# 37  The Czeżowskis smuggled food into the ghetto f...
# 38  The Czeżowskis sheltered eight members of the ...
# 41  Professor Czezowski obtained “Aryan” documents...
# 44  being persecuted. i haven’t eaten for three da...
# 47  being persecuted. i haven’t eaten for three da...
# 49  being persecuted. i haven’t eaten for three da...
# 54  saving jews his life’s mission. he let his hou...
# 57  saving jews his life’s mission. he let his hou...
# 59  saving jews his life’s mission. he let his hou...
# 64  ghetto and, at great personal risk, smuggled o...
# 67  ghetto and, at great personal risk, smuggled o...
# 69  ghetto and, at great personal risk, smuggled o...
# 74  persecuted. i haven’t eaten for three days. pl...
# 75  on, kowalski decided to make saving jews his l...
# 76  a qualified engineer and colonel in the polish...
#
#                                 Rescuing_phrases-name        Full Name  \
# 0   Ludwig Wörl (1906-1967) was first arrested by ...      Ludwig Wörl
# 1   In 1942, Ludwig Wörl (1906-1967) was sent to A...      Ludwig Wörl
# 2   Ludwig Wörl (1906-1967) was first arrested by ...      Ludwig Wörl
# 3   In 1942, Ludwig Wörl (1906-1967) was sent to A...      Ludwig Wörl
# 4   Appointed as the Lagerälteste (the camp elder)...     Lagerälteste
# 6   Appointed as the Lagerälteste (the camp elder)...     Lagerälteste
# 8                                                 NaN             None
# 9   Ludwig Wörl (1906-1967) also put Ludwig Wörl (...      Ludwig Wörl
# 11                                                NaN             None
# 12  Ludwig Wörl (1906-1967) would forge selection ...      Ludwig Wörl
# 13                                                NaN             None
# 14  Here, again, Wörl made Wörl beneficial influen...             Wörl
# 16  Even prisoners with tuberculosis were able to ...             None
# 17  Even prisoners with tuberculosis were able to ...             None
# 18  At the time of the evacuation of Auschwitz, Wö...             Wörl
# 19                                                NaN             None
# 20  Johann Pscheidt sent each one of The fugitives...  Johann Pscheidt
# 21  As part of the effort to locate Adolf Eichmann...   Adolf Eichmann
# 24  Johann Pscheidt sent each one of The fugitives...  Johann Pscheidt
# 25  As part of the effort to locate Adolf Eichmann...   Adolf Eichmann
# 28  In the beginning of 1943, when the Jews of the...  Johann Pscheidt
# 30                                                NaN             None
# 31  Johann Pscheidt also gave the Jewish workers t...  Johann Pscheidt
# 33  Johann Pscheidt also gave the Jewish workers t...  Johann Pscheidt
# 35  Without revealing Johann Pscheidt identity, Jo...  Johann Pscheidt
# 37                                                NaN             None
# 38  Professor Czezowski also sheltered a Jewish re...        Czezowski
# 41  In time, Professor Czezowski obtained “Aryan” ...        Czezowski
# 44  Kowalski immediately did as requested, and arr...         Kowalski
# 47  Kowalski let a friend’s house be used as a she...         Kowalski
# 49  Before the deportation of the remnants of the ...         Kowalski
# 54  Kowalski immediately did as requested, and arr...         Kowalski
# 57  Kowalski let a friend’s house be used as a she...         Kowalski
# 59  Before the deportation of the remnants of the ...         Kowalski
# 64  Kowalski immediately did as requested, and arr...         Kowalski
# 67  Kowalski let a friend’s house be used as a she...         Kowalski
# 69  Before the deportation of the remnants of the ...         Kowalski
# 74                                                NaN             None
# 75                                                NaN             None
# 76                                                NaN             None
#
#       First Name Last Name           Rescued Date
# 0         Ludwig      Wörl              1906-1967
# 1         Ludwig      Wörl                   1942
# 2         Ludwig      Wörl              1906-1967
# 3         Ludwig      Wörl                   1942
# 4   Lagerälteste      None                   None
# 6   Lagerälteste      None                   None
# 8           None      None                   None
# 9         Ludwig      Wörl              1906-1967
# 11          None      None                   None
# 12        Ludwig      Wörl              1906-1967
# 13          None      None                   None
# 14          Wörl      None                   None
# 16          None      None                   None
# 17          None      None                   None
# 18          Wörl      None                   None
# 19          None      None                   None
# 20        Johann  Pscheidt                   None
# 21         Adolf  Eichmann                   None
# 24        Johann  Pscheidt                   None
# 25         Adolf  Eichmann                   None
# 28        Johann  Pscheidt  the beginning of 1943
# 30          None      None                   None
# 31        Johann  Pscheidt                   None
# 33        Johann  Pscheidt                   None
# 35        Johann  Pscheidt                   None
# 37          None      None                   None
# 38     Czezowski      None              July 1944
# 41     Czezowski      None                   None
# 44      Kowalski      None                   None
# 47      Kowalski      None                   None
# 49      Kowalski      None                   None
# 54      Kowalski      None                   None
# 57      Kowalski      None                   None
# 59      Kowalski      None                   None
# 64      Kowalski      None                   None
# 67      Kowalski      None                   None
# 69      Kowalski      None                   None
# 74          None      None                   None
# 75          None      None                   None
# 76          None      None                   None

# %%
table_6.to_csv('3415_SPACY_All_Rescuers_Dates.xlsx', index = False)

# %%
# 문장 처리
# doc = nlp(sentence)

# 사람(Entity) 추출
people = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]
print("Detected people:", people)

# 의존성 파싱으로 주어-동사 관계 분석
for token in doc:
    if token.dep_ == "nsubj" and token.head.lemma_ == "help":
        print(f"Subject: {token.text}, Verb: {token.head.text}")
# Out:
# Detected people: ['Vashem', 'Werner Krumme']

# %%
3415_SPACY_All_Rescuers.XLS

# %%
output_file_name = '3415_SPACY_All_Names.xlsx'
output.to_csv(f'./output/{output_file_name}')
