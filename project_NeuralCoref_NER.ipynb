# %%
# ENV (NLP)

# %% [markdown]
# # 0. Read Source Data & Preprocessing

# %%
import pandas as pd

# %%
data = pd.read_excel('./data/3415_All_STORIES_Updated_ver02.xlsx', index_col = None, header = 0)

# %%
# Function to extract story content after the names

def extract_story(text):
    # Step 1: Split the text by line breaks
    lines = text.strip().split('\n')

    # Step 2: Detect the start of the story (the first longer segment, which should be a complete sentence)
    story_started = False
    story_lines = []
    
    for line in lines:
        # If the line contains more than a few words (let's say more than 3), assume it's the start of the story
        if len(line.split()) > 3:
            story_started = True
        # Once we detect the start of the story, append the rest of the lines
        if story_started:
            story_lines.append(line)
    
    # Step 3: Combine the story lines into a single string and return the result
    return ' '.join(story_lines).strip()

# %%
data['STORY TEXT'] = data['STORY TEXT'].apply(extract_story)

# %%
# we have
# 3414 of stories
data
# Out:
#       STORY ID                                         STORY TEXT
# 0          1.0  Ludwig Wörl (1906-1967) spent 11 years of his ...
# 1          2.0  Johann Pscheidt was born in the city of Radaut...
# 2          3.0  Even before the war, Professor Tadeusz Czeżows...
# 3          4.0  During the occupation, Władysław Kowalski, a q...
# 4          6.0  Władysława Choms, the wife of a major in the P...
# ...        ...                                                ...
# 3409   13524.0  Mordechai Wulkan (b. 1910) and his wife, Chaja...
# 3410   13611.0  Sala Armel-Goldhar lived with her parents, Isr...
# 3411    5257.0  Following Helena Zienowicz’s graduation from t...
# 3412    3053.0  Before the war, Badowski Stefan Franciszek liv...
# 3413    4481.0  In July 1942, during the large-scale Aktion in...
#
# [3414 rows x 2 columns]

# %% [markdown]
# # 1. Milestone 1: Find Names - NER & Co-reference Resolution

# %% [markdown]
# ## 1.1 Find all Names: Simple NER: Start with SPACY Package and model “en_core_web_md” + "en_coreference_web_trf"

# %%
import spacy
import neuralcoref
from spacy import displacy

# %%
# !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.4.1/en_core_web_md-3.4.1-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 26.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from en-core-web-md==3.4.1) (3.4.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (8.1.12)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.7.0)
# Requirement already satisfied: pathy>=0.3.5 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (4.66.5)
# Requirement already satisfied: numpy>=1.15.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.10.18)
# Requirement already satisfied: jinja2 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.1.4)
# Requirement already satisfied: setuptools in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.4.0)
# Requirement already satisfied: language-data>=1.2 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.2.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /Users/minjoo/opt/anaconda3/envs/ner/lib/python3.9/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.2.0)
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.4.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
# Load SpaCy's English model
nlp = spacy.load('en_core_web_md')

# Add neuralcoref to SpaCy's pipeline
neuralcoref.add_to_pipe(nlp)

# %% [markdown]
# ## Coreference Resolution

# %%
# import tqdm to track a progress
from tqdm import tqdm
tqdm.pandas()

# %%
data['STORY TEXT'] = data['STORY TEXT'].progress_apply(lambda row : nlp(row)._.coref_resolved)
data.to_csv('./drafts/3415_all_coref_data.csv', index = False)
# Out:
# 100%|██████████| 3414/3414 [1:39:23<00:00,  1.75s/it]

# %%
data = pd.read_csv('/drafts/3415_all_coref_data.csv')

# %% [markdown]
# ### Separate into sentences, find Named Entity (PERSON) and make a dataframe

# %%
# Create an empty list to store results
results = []

# Function to extract PERSON entities and their sentences from each story
def extract_person_and_sentence(row):
    story_id = row['STORY ID']
    story_text = row['STORY TEXT']
    
    # Parse the story text using Spacy
    doc = nlp(story_text)
    
    # For each sentence in the document, check for PERSON entities and store the result
    for sentence in doc.sents:
        for entity in sentence.ents:
            if entity.label_ == 'PERSON':
                results.append({
                    'storynumber': story_id,
                    'name': entity.text,
                    'sentence': sentence.text
                })

# %%
# Apply the function to each row in the DataFrame
data.progress_apply(extract_person_and_sentence, axis=1)
# Out:
#   3%|▎         | 114/3414 [01:39<48:02,  1.14it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-820e090094b5> in <module>
#       1 # Apply the function to each row in the DataFrame
# ----> 2 data.progress_apply(extract_person_and_sentence, axis=1)
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/tqdm/std.py in inner(df, func, *args, **kwargs)
#     915                 # on the df using our wrapper (which provides bar updating)
#     916                 try:
# --> 917                     return getattr(df, df_function)(wrapper, **kwargs)
#     918                 finally:
#     919                     t.close()
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/tqdm/std.py in wrapper(*args, **kwargs)
#     910                     # take a fast or slow code path; so stop when t.total==t.n
#     911                     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 912                     return func(*args, **kwargs)
#     913
#     914                 # Apply the provided function (in **kwargs)
#
# <ipython-input-15-98c3adc6d4a0> in extract_person_and_sentence(row)
#       8
#       9     # Parse the story text using Spacy
# ---> 10     doc = nlp(story_text)
#      11
#      12     # For each sentence in the document, check for PERSON entities and store the result
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     383             if not hasattr(proc, "__call__"):
#     384                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 385             doc = proc(doc, **component_cfg.get(name, {}))
#     386             if doc is None:
#     387                 raise ValueError(Errors.E005.format(name=name))
#
# neuralcoref.pyx in neuralcoref.neuralcoref.NeuralCoref.__call__()
#
# neuralcoref.pyx in neuralcoref.neuralcoref.NeuralCoref.predict()
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/neural/_classes/feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/check.py in checked_function(wrapped, instance, args, kwargs)
#     149                     raise ExpectedTypeError(check, ["Callable"])
#     150                 check(arg_id, fix_args, kwargs)
# --> 151         return wrapped(*args, **kwargs)
#     152
#     153     def arg_check_adder(func):
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/neural/_classes/relu.py in predict(self, input__BI)
#      10     @check.arg(1, has_shape(("nB", "nI")))
#      11     def predict(self, input__BI):
# ---> 12         output__BO = Affine.predict(self, input__BI)
#      13         output__BO = self.ops.relu(output__BO, inplace=False)
#      14         return output__BO
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/check.py in checked_function(wrapped, instance, args, kwargs)
#     149                     raise ExpectedTypeError(check, ["Callable"])
#     150                 check(arg_id, fix_args, kwargs)
# --> 151         return wrapped(*args, **kwargs)
#     152
#     153     def arg_check_adder(func):
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/neural/_classes/affine.py in predict(self, input__BI)
#      54     @check.arg(1, has_shape(("nB", "nI")))
#      55     def predict(self, input__BI):
# ---> 56         output = self.ops.gemm(input__BI, self.W, trans2=True)
#      57         output += self.b
#      58         return output
#
# KeyboardInterrupt:

# %%
# Convert the list of results to a DataFrame
table_1 = pd.DataFrame(results)

# %%
for id, story in zip(data['STORY ID'], data['STORY TEXT']):
    sentences = [i for i in nlp(story).sents]
    for sentence in sentences:
        for entity in sentence.ents:
            if entity.label_ == 'PERSON':
                stc = str(sentence)
                new_row = {'storynumber' : id, 'name' : entity.text, 'sentence' : stc}
                table_1.loc[len(table_1)] = new_row
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-acb5b8bd73dc> in <module>
#       1 for id, story in zip(data['STORY ID'], data['STORY TEXT']):
# ----> 2     sentences = [i for i in nlp(story).sents]
#       3     for sentence in sentences:
#       4         for entity in sentence.ents:
#       5             if entity.label_ == 'PERSON':
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     383             if not hasattr(proc, "__call__"):
#     384                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 385             doc = proc(doc, **component_cfg.get(name, {}))
#     386             if doc is None:
#     387                 raise ValueError(Errors.E005.format(name=name))
#
# neuralcoref.pyx in neuralcoref.neuralcoref.NeuralCoref.__call__()
#
# neuralcoref.pyx in neuralcoref.neuralcoref.NeuralCoref.predict()
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/neural/_classes/feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/check.py in checked_function(wrapped, instance, args, kwargs)
#     149                     raise ExpectedTypeError(check, ["Callable"])
#     150                 check(arg_id, fix_args, kwargs)
# --> 151         return wrapped(*args, **kwargs)
#     152
#     153     def arg_check_adder(func):
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/neural/_classes/relu.py in predict(self, input__BI)
#      10     @check.arg(1, has_shape(("nB", "nI")))
#      11     def predict(self, input__BI):
# ---> 12         output__BO = Affine.predict(self, input__BI)
#      13         output__BO = self.ops.relu(output__BO, inplace=False)
#      14         return output__BO
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/check.py in checked_function(wrapped, instance, args, kwargs)
#     149                     raise ExpectedTypeError(check, ["Callable"])
#     150                 check(arg_id, fix_args, kwargs)
# --> 151         return wrapped(*args, **kwargs)
#     152
#     153     def arg_check_adder(func):
#
# ~/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/neural/_classes/affine.py in predict(self, input__BI)
#      54     @check.arg(1, has_shape(("nB", "nI")))
#      55     def predict(self, input__BI):
# ---> 56         output = self.ops.gemm(input__BI, self.W, trans2=True)
#      57         output += self.b
#      58         return output
#
# KeyboardInterrupt:

# %%
table_1
# Out:
#      storynumber           name  \
# 0            1.0    Ludwig Wörl
# 1            1.0    Ludwig Wörl
# 2            1.0    Ludwig Wörl
# 3            1.0    Ludwig Wörl
# 4            1.0    Ludwig Wörl
# ..           ...            ...
# 591         33.0        Strauss
# 592         33.0        Strauss
# 593         33.0  Werner Krumme
# 594         33.0         Vashem
# 595         33.0  Werner Krumme
#
#                                               sentence
# 0    Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 1    Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 2    Ludwig Wörl (1906-1967) was first arrested by ...
# 3    After spending some nine months in a dark dete...
# 4    In 1942, Ludwig Wörl (1906-1967) was sent to A...
# ..                                                 ...
# 591  The Jewish pharmacist Strauss was likewise ass...
# 592  The Jewish pharmacist Strauss was likewise ass...
# 593  Werner Krumme himself was released from Auschw...
# 594  On June 16, 1964, Yad Vashem recognized Werner...
# 595  On June 16, 1964, Yad Vashem recognized Werner...
#
# [596 rows x 3 columns]

# %%
# Extract Output
table_1.to_csv('./output/3415_SPACY_All_Names.xlsx', index = False)

# %%
table_1 = pd.read_csv('./output/3415_SPACY_All_Names.xlsx')

# %% [markdown]
# ## 1.2 Find Rescuers Names: Filtering Only Rescuers (Righteous Among the Nations) Names

# %% [markdown]
# ### 1.2.1.1 Step 1: Preparing a table of filtered sentences: “Rescuing Phrases-Name” - Lexicon-based

# %%
# Table 1
table_1
# table1 = pd.read_excel('./output/3415_SPACY_All_Names.xlsx', index = False)
# Out:
#      storynumber           name  \
# 0            1.0    Ludwig Wörl
# 1            1.0    Ludwig Wörl
# 2            1.0    Ludwig Wörl
# 3            1.0    Ludwig Wörl
# 4            1.0    Ludwig Wörl
# ..           ...            ...
# 591         33.0        Strauss
# 592         33.0        Strauss
# 593         33.0  Werner Krumme
# 594         33.0         Vashem
# 595         33.0  Werner Krumme
#
#                                               sentence
# 0    Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 1    Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 2    Ludwig Wörl (1906-1967) was first arrested by ...
# 3    After spending some nine months in a dark dete...
# 4    In 1942, Ludwig Wörl (1906-1967) was sent to A...
# ..                                                 ...
# 591  The Jewish pharmacist Strauss was likewise ass...
# 592  The Jewish pharmacist Strauss was likewise ass...
# 593  Werner Krumme himself was released from Auschw...
# 594  On June 16, 1964, Yad Vashem recognized Werner...
# 595  On June 16, 1964, Yad Vashem recognized Werner...
#
# [596 rows x 3 columns]

# %%
# Table 2 (lexicon)
table_2 = pd.read_excel('./data/Final_Lexicon_Updated.xlsx')

# %%
table_2
# Out:
#       Story ID        Rescuing Verb  \
# 0          1.0                 sent
# 1          1.0                 sent
# 2          1.0             employed
# 3          1.0               saving
# 4          1.0  put himself at risk
# ...        ...                  ...
# 8922    5257.0         looked after
# 8923    5257.0         looked after
# 8924    5257.0            sheltered
# 8925    5257.0             obtained
# 8926    5257.0               taught
#
#                                         Rescuing Phrase
# 0     his life as a political prisoner in nazi conce...
# 1     to the camp’s joinery and later, as a trained ...
# 2     personnel. appointed as the lagerälteste (the ...
# 3     lagerälteste (the camp elder) of the hospital ...
# 4     barracks, wörl, against the express orders of ...
# ...                                                 ...
# 8922  Helena looked after the children, obtaining "A...
# 8923  Helena looked after the children, obtaining "A...
# 8924  Initially, they were only supposed to stay wit...
# 8925  Helenapresented the fugitives as her brother’s...
# 8926  Helenapresented the fugitives as her brother’s...
#
# [8927 rows x 3 columns]

# %% [markdown]
# #### Trying rescuing verb 등장하는 부분을 lexicon 의 Rescuing Phrase 활용해서 Story 에서 찾기 중인데 쉽지않음

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# /Users/minjoo/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# Step 1: Merge the two dataframes on 'STORY ID'
merged_df = pd.merge(table_2, data, on='Story ID')

# %%
# Step 2: Function to find and replace 'Rescuing Phrase' with the best match in 'STORY TEXT'
def update_rescuing_phrase(row):
    story_text = row['Story Text']
    rescuing_phrase = row['Rescuing Phrase']
    
    # Split the STORY TEXT into sentences
    sentences = story_text.split('. ')
    
    # Split the Rescuing Phrase into its own sentences for matching
    rescuing_sentences = rescuing_phrase.split('. ')
    
    # Track which sentences should be updated
    updated_sentences = []
    
    # Iterate through each rescuing sentence and match it to sentences in the story
    for resc_sentence in rescuing_sentences:
        match = process.extractOne(resc_sentence, sentences, scorer=fuzz.partial_ratio)
        
        # If a good match is found, replace the matched sentence with the rescuing sentence
        if match and match[1] > 80:  # You can adjust the threshold as needed
            matched_sentence = match[0]
            updated_sentences.append(matched_sentence)
            sentences[sentences.index(matched_sentence)] = resc_sentence  # Replace in STORY TEXT
            
    # Join the updated sentences back together
    return '. '.join(sentences)

# %%
# Step 3: Apply the function to each row to update the 'Rescuing Phrase'
merged_df['Updated Rescuing Phrase'] = merged_df.apply(update_rescuing_phrase, axis=1)

# %%
merged_df
# Out:
#     Story ID        Rescuing Verb  \
# 0        1.0                 sent
# 1        1.0                 sent
# 2        1.0             employed
# 3        1.0               saving
# 4        1.0  put himself at risk
# ..       ...                  ...
# 84      29.0                 sent
# 85      29.0              helping
# 86      29.0               helped
# 87      30.0                 sent
# 88      33.0                 sent
#
#                                       Rescuing Phrase  \
# 0   his life as a political prisoner in nazi conce...
# 1   to the camp’s joinery and later, as a trained ...
# 2   personnel. appointed as the lagerälteste (the ...
# 3   lagerälteste (the camp elder) of the hospital ...
# 4   barracks, wörl, against the express orders of ...
# ..                                                ...
# 84  feiner, the bund representative and adolf berm...
# 85  in december 1942, bartoszewski (whose undercov...
# 86  the polish public. he published many articles ...
# 87  the world looks on”), describing the warsaw gh...
# 88  his wife were held in prison in germany until ...
#
#                                            Story Text  \
# 0   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 1   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 2   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 3   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 4   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# ..                                                ...
# 84  From September 1942, even before the establish...
# 85  From September 1942, even before the establish...
# 86  From September 1942, even before the establish...
# 87  During the occupation, Kann organized the Scou...
# 88  Three months after Hitler’s rise to power, in ...
#
#                               Updated Rescuing Phrase
# 0   his life as a political prisoner in nazi conce...
# 1   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 2   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 3   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 4   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# ..                                                ...
# 84  the. When Zegota was established in December 1...
# 85  From September 1942, even before the establish...
# 86  From September 1942, even before the establish...
# 87  During the occupation, Kann organized the Scou...
# 88  Three months after Hitler’s rise to power, in ...
#
# [89 rows x 5 columns]

# %%
merged_df.iloc[-1]['Rescuing Phrase']
# Out:
# 'his wife were held in prison in germany until january 31, 1943, and then deported to auschwitz. mrs. krumme was sent to the gas chambers. an ss-man notified werner of her death, in may 1943, with the following words: “be happy'

# %%
merged_df.iloc[-1]['Updated Rescuing Phrase']
# Out:
# 'Three months after Hitler’s rise to power, in May 1933, Werner Krumme (b. 1909 in Dortmund) married a Jewish wife. Despite official discrimination and frequent harassment by the Gestapo, Krumme stood by Krumme and refused to divorce a Jewish wife. mrs. Krumme, Renate and Anita Lasker, to flee to unoccupied France. his wife were held in prison in germany until january 31, 1943, and then deported to auschwitz. krumme was sent to the gas chambers. an ss-man notified werner of her death, in may 1943, with the following words: “be happy.  Werner used Werner position to falsify so-called selection lists and to assign Jews to work units with relatively tolerable conditions, which increased the chances of Jews survival. Werner thus added the names of Ernst Krinski and Peter Schwartz to a list of a transport that was leaving Auschwitz to the concentration camp of “Warschau,” where no gassing of prisoners took place. The Jewish pharmacist Strauss was likewise assigned by The Jewish pharmacist Strauss to the SS pharmacy in Auschwitz, where The Jewish pharmacist Strauss was able to survive. Werner Krumme himself was released from Auschwitz on July 7, 1944. On June 16, 1964, Yad Vashem recognized Werner Krumme himself as Righteous Among the Nations.'

# %%
# Step 2: Function to find and replace 'Rescuing Phrase' in 'STORY TEXT'
def replace_rescuing_phrase(row):
    story_text = row['Story Text']
    rescuing_phrase = row['Rescuing Phrase']
    
    # Find the closest matching sentence in the STORY TEXT using fuzzy matching
    match = process.extractOne(rescuing_phrase, story_text.split('. '), scorer=fuzz.partial_ratio)
    
    # If a match is found, replace it with the rescuing phrase
    if match and match[1] > 80:  # Match score should be high enough, e.g., above 80
        matched_sentence = match[0]
        new_story_text = story_text.replace(matched_sentence, rescuing_phrase)
        return new_story_text
    else:
        return story_text  # If no good match, return the original story text

# %%
# Step 3: Apply the function to each row to replace the rescuing phrase
merged_df['Updated STORY TEXT'] = merged_df.apply(replace_rescuing_phrase, axis=1)

# %%
merged_df
# Out:
#     Story ID        Rescuing Verb  \
# 0        1.0                 sent
# 1        1.0                 sent
# 2        1.0             employed
# 3        1.0               saving
# 4        1.0  put himself at risk
# ..       ...                  ...
# 84      29.0                 sent
# 85      29.0              helping
# 86      29.0               helped
# 87      30.0                 sent
# 88      33.0                 sent
#
#                                       Rescuing Phrase  \
# 0   his life as a political prisoner in nazi conce...
# 1   to the camp’s joinery and later, as a trained ...
# 2   personnel. appointed as the lagerälteste (the ...
# 3   lagerälteste (the camp elder) of the hospital ...
# 4   barracks, wörl, against the express orders of ...
# ..                                                ...
# 84  feiner, the bund representative and adolf berm...
# 85  in december 1942, bartoszewski (whose undercov...
# 86  the polish public. he published many articles ...
# 87  the world looks on”), describing the warsaw gh...
# 88  his wife were held in prison in germany until ...
#
#                                            Story Text  \
# 0   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 1   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 2   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 3   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 4   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# ..                                                ...
# 84  From September 1942, even before the establish...
# 85  From September 1942, even before the establish...
# 86  From September 1942, even before the establish...
# 87  During the occupation, Kann organized the Scou...
# 88  Three months after Hitler’s rise to power, in ...
#
#                                    Updated STORY TEXT
# 0   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 1   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 2   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 3   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# 4   Ludwig Wörl (1906-1967) spent 11 years of Ludw...
# ..                                                ...
# 84  From September 1942, even before the establish...
# 85  From September 1942, even before the establish...
# 86  From September 1942, even before the establish...
# 87  During the occupation, Kann organized the Scou...
# 88  Three months after Hitler’s rise to power, in ...
#
# [89 rows x 5 columns]

# %% [markdown]
# ### Making Table 3 Starts

# %%
#Table3
table_3 = pd.DataFrame(columns = ['Story ID','Rescuing Verb', 'Rescuing_phrases-name'])

# %%
# input
# Table1
table_1['sentence'][0]
# check if rescuing verb appear in the sentence. (Lexicon reference - same story ID)
# If there is rescuing verb existed,
# (Also name)
# add this sentence to a new table Table3
# Out:
# 'Ludwig Wörl (1906-1967) spent 11 years of Ludwig Wörl (1906-1967) life as a political prisoner in Nazi concentration camps.  '

# %%
for row in tqdm(table_1.itertuples(), total = table_1.shape[0]):
    # storyid = row.storynumber
    # 본 회차 스토리에서 찾아내야하는 verb 목록 불러오고
    verbs_to_find = list(set(table_2[table_2['Story ID'] == row.storynumber]['Rescuing Verb']))

    for verb in verbs_to_find:
        if verb in row.sentence:
            new_row = {'Story ID' : row.storynumber, 'Rescuing Verb' : str(verb), 'Rescuing_phrases-name' : row.sentence}
            table_3.loc[len(table_3)] = new_row
# Out:
# 100%|██████████| 596/596 [00:00<00:00, 1757.99it/s]

# %%
table_3
# Out:
#      Story ID Rescuing Verb                              Rescuing_phrases-name
# 0         1.0          sent  Ludwig Wörl (1906-1967) was first arrested by ...
# 1         1.0          sent  In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 2         1.0      employed  Appointed as the Lagerälteste (the camp elder)...
# 3         1.0        saving  Appointed as the Lagerälteste (the camp elder)...
# 4         1.0      employed  Appointed as the Lagerälteste (the camp elder)...
# ..        ...           ...                                                ...
# 177      29.0          sent  As part of Ludwik”) underground activity, Wład...
# 178      29.0        helped  The author, Rachel Auerbach, and Dr. A. Berman...
# 179      29.0        helped  The author, Rachel Auerbach, and Dr. A. Berman...
# 180      30.0          sent  The tract, which was also sent abroad, also co...
# 181      33.0          sent               Krumme was sent to the gas chambers.
#
# [182 rows x 3 columns]

# %%
# Table_4 (Merge table_2 and table_3)
# table_4: Complete Lexicon Structure Example
table_4 = pd.merge(table_2, table_3, how = 'left', on = ['Story ID','Rescuing Verb'])

# %%
table_4
# Out:
#       Story ID Rescuing Verb  \
# 0          1.0          sent
# 1          1.0          sent
# 2          1.0          sent
# 3          1.0          sent
# 4          1.0      employed
# ...        ...           ...
# 9168    5257.0  looked after
# 9169    5257.0  looked after
# 9170    5257.0     sheltered
# 9171    5257.0      obtained
# 9172    5257.0        taught
#
#                                         Rescuing Phrase  \
# 0     his life as a political prisoner in nazi conce...
# 1     his life as a political prisoner in nazi conce...
# 2     to the camp’s joinery and later, as a trained ...
# 3     to the camp’s joinery and later, as a trained ...
# 4     personnel. appointed as the lagerälteste (the ...
# ...                                                 ...
# 9168  Helena looked after the children, obtaining "A...
# 9169  Helena looked after the children, obtaining "A...
# 9170  Initially, they were only supposed to stay wit...
# 9171  Helenapresented the fugitives as her brother’s...
# 9172  Helenapresented the fugitives as her brother’s...
#
#                                   Rescuing_phrases-name
# 0     Ludwig Wörl (1906-1967) was first arrested by ...
# 1     In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 2     Ludwig Wörl (1906-1967) was first arrested by ...
# 3     In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 4     Appointed as the Lagerälteste (the camp elder)...
# ...                                                 ...
# 9168                                                NaN
# 9169                                                NaN
# 9170                                                NaN
# 9171                                                NaN
# 9172                                                NaN
#
# [9173 rows x 4 columns]

# %%
# drop duplicated rows
table_4.drop_duplicates(inplace = True)

# %%
table_4
# Out:
#       Story ID Rescuing Verb  \
# 0          1.0          sent
# 1          1.0          sent
# 2          1.0          sent
# 3          1.0          sent
# 4          1.0      employed
# ...        ...           ...
# 9167    4481.0    recognized
# 9168    5257.0  looked after
# 9170    5257.0     sheltered
# 9171    5257.0      obtained
# 9172    5257.0        taught
#
#                                         Rescuing Phrase  \
# 0     his life as a political prisoner in nazi conce...
# 1     his life as a political prisoner in nazi conce...
# 2     to the camp’s joinery and later, as a trained ...
# 3     to the camp’s joinery and later, as a trained ...
# 4     personnel. appointed as the lagerälteste (the ...
# ...                                                 ...
# 9167  On January 17, 1990, Yad Vashem recognized Józ...
# 9168  Helena looked after the children, obtaining "A...
# 9170  Initially, they were only supposed to stay wit...
# 9171  Helenapresented the fugitives as her brother’s...
# 9172  Helenapresented the fugitives as her brother’s...
#
#                                   Rescuing_phrases-name
# 0     Ludwig Wörl (1906-1967) was first arrested by ...
# 1     In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 2     Ludwig Wörl (1906-1967) was first arrested by ...
# 3     In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 4     Appointed as the Lagerälteste (the camp elder)...
# ...                                                 ...
# 9167                                                NaN
# 9168                                                NaN
# 9170                                                NaN
# 9171                                                NaN
# 9172                                                NaN
#
# [8983 rows x 4 columns]

# %%
table_4.to_csv('./drafts/table_4.xlsx', index = False)

# %% [markdown]
# ### 1.2.1.2 Step 2:“Rescuers Names filtering” - Step-by-Step Breakdown

# %%
table_4 = pd.read_csv('./drafts/table_4.xlsx')

# %%
table_4
# Out:
#       Story ID Rescuing Verb  \
# 0          1.0          sent
# 1          1.0          sent
# 2          1.0          sent
# 3          1.0          sent
# 4          1.0      employed
# ...        ...           ...
# 9167    4481.0    recognized
# 9168    5257.0  looked after
# 9170    5257.0     sheltered
# 9171    5257.0      obtained
# 9172    5257.0        taught
#
#                                         Rescuing Phrase  \
# 0     his life as a political prisoner in nazi conce...
# 1     his life as a political prisoner in nazi conce...
# 2     to the camp’s joinery and later, as a trained ...
# 3     to the camp’s joinery and later, as a trained ...
# 4     personnel. appointed as the lagerälteste (the ...
# ...                                                 ...
# 9167  On January 17, 1990, Yad Vashem recognized Józ...
# 9168  Helena looked after the children, obtaining "A...
# 9170  Initially, they were only supposed to stay wit...
# 9171  Helenapresented the fugitives as her brother’s...
# 9172  Helenapresented the fugitives as her brother’s...
#
#                                   Rescuing_phrases-name
# 0     Ludwig Wörl (1906-1967) was first arrested by ...
# 1     In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 2     Ludwig Wörl (1906-1967) was first arrested by ...
# 3     In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 4     Appointed as the Lagerälteste (the camp elder)...
# ...                                                 ...
# 9167                                                NaN
# 9168                                                NaN
# 9170                                                NaN
# 9171                                                NaN
# 9172                                                NaN
#
# [8983 rows x 4 columns]

# %% [markdown]
# #### 0917 Dependency Parsing.. hmm

# %%
table_4.dropna(inplace = True)

# %%
table_4.iloc[0]
# Out:
# Story ID                                                               1.0
# Rescuing Verb                                                         sent
# Rescuing Phrase          his life as a political prisoner in nazi conce...
# Rescuing_phrases-name    Ludwig Wörl (1906-1967) was first arrested by ...
# Name: 0, dtype: object

# %%
table_4.iloc[4]['Rescuing_phrases-name']
# Out:
# 'Appointed as the Lagerälteste (the camp elder) of the hospital barracks, Wörl, against the express orders of the SS, employed Jewish doctors, thus saving Jewish doctors from certain death.'

# %%
txt = 'Ludwig Wörl (1906-1967) was first arrested by the Gestapo in 1934, and sent to Dachau for distributing a pamphlet in which the citizens of Munich were informed about the horrors of the camp.'

# %%
doc = nlp(txt)

# %%
for token in doc :
    if token.text.lower() == 'sent':
        print(token.dep_)
        print([token for token in token.children])
        print([token.dep_ for token in token.children])
# Out:
# conj
# [to, for]
# ['dative', 'prep']

# %%
# 09-17 !!!!!!!!
# Function to find the rescuer (subject) for each sentence
def find_rescuer(df):
    sentence = df['Rescuing Phrase']
    rescuing_verb = df['Rescuing Verb']
    
    # Skip NaN values
    if pd.isna(sentence):
        return None
    
    # Process sentence with Spacy
    doc = nlp(sentence)
    
    # If the verb is multi-word (like "put himself at risk"), we handle it separately.
    if rescuing_verb in sentence:
        # Find the subject (nsubj) related to the rescuing verb
        for token in doc:
            if rescuing_verb.split()[0] == token.lemma_ or token.text == rescuing_verb.split()[0]:
                # Find the subject (nsubj) linked to the verb
                subject = [child for child in token.children if child.dep_ == "nsubj"]
                if subject:
                    return subject[0].text  # Return the first subject found
    
    return None  # Return None if no subject is found

# %%
# 주어진 rescuing verb와 관련된 주어(구조하는 사람) 찾기
def find_rescuer(df):
    # 문장과 rescuing verb
    sentence = df['Rescuing_phrases-name']
    rescuing_verb = df['Rescuing Verb']
    
    # 문장을 Spacy로 파싱
    doc = nlp(sentence)
    
    # 구조하는 사람(주어)을 저장할 리스트
    # rescuers = []
    
    # 문장에서 주어진 rescuing verb의 텍스트와 일치하는 주어 찾기
    # subject = None
    rescuer = None
    for token in doc:
        
        # if token.dep_ == 'nsubj':
        #     subject = token.text

        # token.text가 주어진 rescuing verb와 일치할 경우
        if token.text.lower() == rescuing_verb.lower():  # 대소문자 구분 무시
            # 해당 동사에 연결된 주어 찾기 (nsubj)
            for child in token.children:
                if child.dep_ == "nsubj":
                    rescuer = child.text
    
    # 결과 반환 (찾은 구조하는 사람 또는 None)
    if rescuer:
        return rescuer
    # else:
    #     return subject
    # if rescuers else None

# %%
sample_table_4 = table_4[:40]

# %%
# 데이터프레임에서 rescuing verb와 관련된 주어(구조하는 사람) 찾기
sample_table_4['Rescuer'] = sample_table_4.apply(find_rescuer, axis=1)
# Out:
# /Users/minjoo/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sample_table_4
# Out:
#     Story ID Rescuing Verb                                    Rescuing Phrase  \
# 0        1.0          sent  his life as a political prisoner in nazi conce...
# 1        1.0          sent  his life as a political prisoner in nazi conce...
# 2        1.0          sent  to the camp’s joinery and later, as a trained ...
# 3        1.0          sent  to the camp’s joinery and later, as a trained ...
# 4        1.0      employed  personnel. appointed as the lagerälteste (the ...
# 6        1.0        saving  lagerälteste (the camp elder) of the hospital ...
# 9        1.0        obtain  the ss, employed jewish doctors, thus saving t...
# 11       1.0     treatment  himself at risk in order to obtain at least a ...
# 13       1.0     treatment  himself at risk in order to obtain at least a ...
# 15       1.0         forge  obtain at least a minimum of the required medi...
# 16       1.0     influence  german descent and seniority, put in charge of...
# 18       1.0    protecting  and seniority, put in charge of güntergrube, a...
# 20       1.0      exempted  that they get their due share of food and clot...
# 21       1.0     protected  of food and clothing. even prisoners with tube...
# 22       1.0        helped  them by various subterfuges from the inspectio...
# 23       1.0     dedicated  the infamous death marches. after the war wörl...
# 25       2.0          sent  on the black market. the fugitives came out of...
# 26       2.0          sent  on the black market. the fugitives came out of...
# 29       2.0          sent  to help in the struggle against the nazis. as ...
# 30       2.0          sent  to help in the struggle against the nazis. as ...
# 33       2.0      arranged  with the zionist underground. in the beginning...
# 35       2.0        rescue  he managed, which was situated only a few mete...
# 37       2.0      provided  with food and money. he also gave the jewish w...
# 39       2.0      employed  identity, he helped poor jews in the city with...
# 41       2.0        helped  german. at the beginning of the 1930s, pscheid...
# 44       3.0     sheltered  The Czeżowskis sheltered eight members of the ...
# 47       3.0      obtained  Professor Czezowski obtained “Aryan” documents...
# 50       4.0      arranged  being persecuted. i haven’t eaten for three da...
# 53       4.0      arranged  being persecuted. i haven’t eaten for three da...
# 55       4.0      arranged  being persecuted. i haven’t eaten for three da...
# 60       4.0      arranged  saving jews his life’s mission. he let his hou...
# 63       4.0      arranged  saving jews his life’s mission. he let his hou...
# 65       4.0      arranged  saving jews his life’s mission. he let his hou...
# 70       4.0      arranged  ghetto and, at great personal risk, smuggled o...
# 73       4.0      arranged  ghetto and, at great personal risk, smuggled o...
# 75       4.0      arranged  ghetto and, at great personal risk, smuggled o...
# 80       4.0       shelter  persecuted. i haven’t eaten for three days. pl...
# 83       4.0       shelter  persecuted. i haven’t eaten for three days. pl...
# 85       4.0       shelter  on, kowalski decided to make saving jews his l...
# 88       4.0       shelter  on, kowalski decided to make saving jews his l...
#
#                                 Rescuing_phrases-name    Rescuer
# 0   Ludwig Wörl (1906-1967) was first arrested by ...       None
# 1   In 1942, Ludwig Wörl (1906-1967) was sent to A...       None
# 2   Ludwig Wörl (1906-1967) was first arrested by ...       None
# 3   In 1942, Ludwig Wörl (1906-1967) was sent to A...       None
# 4   Appointed as the Lagerälteste (the camp elder)...       None
# 6   Appointed as the Lagerälteste (the camp elder)...       None
# 9   Ludwig Wörl (1906-1967) also put Ludwig Wörl (...       None
# 11  Ludwig Wörl (1906-1967) also put Ludwig Wörl (...       None
# 13  Here, again, Wörl made Wörl beneficial influen...       None
# 15  Ludwig Wörl (1906-1967) would forge selection ...       Wörl
# 16  Here, again, Wörl made Wörl beneficial influen...       None
# 18  Here, again, Wörl made Wörl beneficial influen...       None
# 20  Even prisoners with tuberculosis were able to ...       Wörl
# 21  Even prisoners with tuberculosis were able to ...       None
# 22  At the time of the evacuation of Auschwitz, Wö...       Wörl
# 23  After the war Wörl, who became chairman of the...       None
# 25  Johann Pscheidt sent each one of The fugitives...   Pscheidt
# 26  As part of the effort to locate Adolf Eichmann...       None
# 29  Johann Pscheidt sent each one of The fugitives...   Pscheidt
# 30  As part of the effort to locate Adolf Eichmann...       None
# 33  In the beginning of 1943, when the Jews of the...   Pscheidt
# 35  In the beginning of 1943, when the Jews of the...       None
# 37  Johann Pscheidt also gave the Jewish workers t...       None
# 39  Johann Pscheidt also gave the Jewish workers t...   Pscheidt
# 41  Without revealing Johann Pscheidt identity, Jo...   Pscheidt
# 44  Professor Czezowski also sheltered a Jewish re...  Czezowski
# 47  In time, Professor Czezowski obtained “Aryan” ...  Czezowski
# 50  Kowalski immediately did as requested, and arr...       None
# 53  Kowalski let a friend’s house be used as a she...       None
# 55  Before the deportation of the remnants of the ...       None
# 60  Kowalski immediately did as requested, and arr...       None
# 63  Kowalski let a friend’s house be used as a she...       None
# 65  Before the deportation of the remnants of the ...       None
# 70  Kowalski immediately did as requested, and arr...       None
# 73  Kowalski let a friend’s house be used as a she...       None
# 75  Before the deportation of the remnants of the ...       None
# 80  Kowalski immediately did as requested, and arr...       None
# 83  Kowalski let a friend’s house be used as a she...       None
# 85  Kowalski immediately did as requested, and arr...       None
# 88  Kowalski let a friend’s house be used as a she...       None

# %% [markdown]
# ### 그냥 이걸로 갈까봐... 첫번째 이름 찾기

# %%
# Function to find the full name of the rescuer, and split it into first name and last name
def extract_name_info(row):
    sentence = row['Rescuing_phrases-name']  # Adjusted column name
    rescuing_verb = row['Rescuing Verb']    # Adjusted column name
    
    # Skip NaN values
    if pd.isna(sentence):
        return pd.Series([None, None, None])  # Return None for full name, first name, and last name
    
    # Process sentence with Spacy
    doc = nlp(sentence)
    
    # Find the full name of the rescuer using NER
    full_name = None
    for ent in doc.ents:
        if ent.label_ == "PERSON":
            full_name = ent.text  # Get the first PERSON entity (assuming it's the rescuer)
            break
    
    if not full_name:
        return pd.Series([None, None, None])  # Return None if no PERSON entity is found
    
    # Split the full name into first and last name
    name_parts = full_name.split()
    if len(name_parts) > 1:
        last_name = name_parts[-1]
        first_name = " ".join(name_parts[:-1])
    else:
        first_name = full_name
        last_name = None  # If no last name, leave it as None
    
    return pd.Series([full_name, first_name, last_name])

# %%
sample_table_4 = table_4[:40]

# %%
sample_table_4
# Out:
#     Story ID        Rescuing Verb  \
# 0        1.0                 sent
# 1        1.0                 sent
# 2        1.0                 sent
# 3        1.0                 sent
# 4        1.0             employed
# 6        1.0               saving
# 8        1.0  put himself at risk
# 9        1.0               obtain
# 11       1.0            treatment
# 13       1.0            treatment
# 15       1.0                forge
# 16       1.0            influence
# 18       1.0           protecting
# 20       1.0             exempted
# 21       1.0            protected
# 22       1.0               helped
# 23       1.0            dedicated
# 25       2.0                 sent
# 26       2.0                 sent
# 29       2.0                 sent
# 30       2.0                 sent
# 33       2.0             arranged
# 35       2.0               rescue
# 37       2.0             provided
# 39       2.0             employed
# 41       2.0               helped
# 43       3.0             smuggled
# 44       3.0            sheltered
# 47       3.0             obtained
# 50       4.0             arranged
# 53       4.0             arranged
# 55       4.0             arranged
# 60       4.0             arranged
# 63       4.0             arranged
# 65       4.0             arranged
# 70       4.0             arranged
# 73       4.0             arranged
# 75       4.0             arranged
# 80       4.0              shelter
# 83       4.0              shelter
#
#                                       Rescuing Phrase  \
# 0   his life as a political prisoner in nazi conce...
# 1   his life as a political prisoner in nazi conce...
# 2   to the camp’s joinery and later, as a trained ...
# 3   to the camp’s joinery and later, as a trained ...
# 4   personnel. appointed as the lagerälteste (the ...
# 6   lagerälteste (the camp elder) of the hospital ...
# 8   barracks, wörl, against the express orders of ...
# 9   the ss, employed jewish doctors, thus saving t...
# 11  himself at risk in order to obtain at least a ...
# 13  himself at risk in order to obtain at least a ...
# 15  obtain at least a minimum of the required medi...
# 16  german descent and seniority, put in charge of...
# 18  and seniority, put in charge of güntergrube, a...
# 20  that they get their due share of food and clot...
# 21  of food and clothing. even prisoners with tube...
# 22  them by various subterfuges from the inspectio...
# 23  the infamous death marches. after the war wörl...
# 25  on the black market. the fugitives came out of...
# 26  on the black market. the fugitives came out of...
# 29  to help in the struggle against the nazis. as ...
# 30  to help in the struggle against the nazis. as ...
# 33  with the zionist underground. in the beginning...
# 35  he managed, which was situated only a few mete...
# 37  with food and money. he also gave the jewish w...
# 39  identity, he helped poor jews in the city with...
# 41  german. at the beginning of the 1930s, pscheid...
# 43  The Czeżowskis smuggled food into the ghetto f...
# 44  The Czeżowskis sheltered eight members of the ...
# 47  Professor Czezowski obtained “Aryan” documents...
# 50  being persecuted. i haven’t eaten for three da...
# 53  being persecuted. i haven’t eaten for three da...
# 55  being persecuted. i haven’t eaten for three da...
# 60  saving jews his life’s mission. he let his hou...
# 63  saving jews his life’s mission. he let his hou...
# 65  saving jews his life’s mission. he let his hou...
# 70  ghetto and, at great personal risk, smuggled o...
# 73  ghetto and, at great personal risk, smuggled o...
# 75  ghetto and, at great personal risk, smuggled o...
# 80  persecuted. i haven’t eaten for three days. pl...
# 83  persecuted. i haven’t eaten for three days. pl...
#
#                                 Rescuing_phrases-name
# 0   Ludwig Wörl (1906-1967) was first arrested by ...
# 1   In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 2   Ludwig Wörl (1906-1967) was first arrested by ...
# 3   In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 4   Appointed as the Lagerälteste (the camp elder)...
# 6   Appointed as the Lagerälteste (the camp elder)...
# 8                                                 NaN
# 9   Ludwig Wörl (1906-1967) also put Ludwig Wörl (...
# 11  Ludwig Wörl (1906-1967) also put Ludwig Wörl (...
# 13  Here, again, Wörl made Wörl beneficial influen...
# 15  Ludwig Wörl (1906-1967) would forge selection ...
# 16  Here, again, Wörl made Wörl beneficial influen...
# 18  Here, again, Wörl made Wörl beneficial influen...
# 20  Even prisoners with tuberculosis were able to ...
# 21  Even prisoners with tuberculosis were able to ...
# 22  At the time of the evacuation of Auschwitz, Wö...
# 23  After the war Wörl, who became chairman of the...
# 25  Johann Pscheidt sent each one of The fugitives...
# 26  As part of the effort to locate Adolf Eichmann...
# 29  Johann Pscheidt sent each one of The fugitives...
# 30  As part of the effort to locate Adolf Eichmann...
# 33  In the beginning of 1943, when the Jews of the...
# 35  In the beginning of 1943, when the Jews of the...
# 37  Johann Pscheidt also gave the Jewish workers t...
# 39  Johann Pscheidt also gave the Jewish workers t...
# 41  Without revealing Johann Pscheidt identity, Jo...
# 43                                                NaN
# 44  Professor Czezowski also sheltered a Jewish re...
# 47  In time, Professor Czezowski obtained “Aryan” ...
# 50  Kowalski immediately did as requested, and arr...
# 53  Kowalski let a friend’s house be used as a she...
# 55  Before the deportation of the remnants of the ...
# 60  Kowalski immediately did as requested, and arr...
# 63  Kowalski let a friend’s house be used as a she...
# 65  Before the deportation of the remnants of the ...
# 70  Kowalski immediately did as requested, and arr...
# 73  Kowalski let a friend’s house be used as a she...
# 75  Before the deportation of the remnants of the ...
# 80  Kowalski immediately did as requested, and arr...
# 83  Kowalski let a friend’s house be used as a she...

# %%
# Apply the function to the DataFrame and store the results in separate columns
sample_table_4[['Full Name', 'First Name', 'Last Name']] = sample_table_4.apply(extract_name_info, axis=1)
# Out:
# /Users/minjoo/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
sample_table_4
# Out:
#     Story ID Rescuing Verb                                    Rescuing Phrase  \
# 0        1.0          sent  his life as a political prisoner in nazi conce...
# 1        1.0          sent  his life as a political prisoner in nazi conce...
# 2        1.0          sent  to the camp’s joinery and later, as a trained ...
# 3        1.0          sent  to the camp’s joinery and later, as a trained ...
# 4        1.0      employed  personnel. appointed as the lagerälteste (the ...
# 6        1.0        saving  lagerälteste (the camp elder) of the hospital ...
# 9        1.0        obtain  the ss, employed jewish doctors, thus saving t...
# 11       1.0     treatment  himself at risk in order to obtain at least a ...
# 13       1.0     treatment  himself at risk in order to obtain at least a ...
# 15       1.0         forge  obtain at least a minimum of the required medi...
# 16       1.0     influence  german descent and seniority, put in charge of...
# 18       1.0    protecting  and seniority, put in charge of güntergrube, a...
# 20       1.0      exempted  that they get their due share of food and clot...
# 21       1.0     protected  of food and clothing. even prisoners with tube...
# 22       1.0        helped  them by various subterfuges from the inspectio...
# 23       1.0     dedicated  the infamous death marches. after the war wörl...
# 25       2.0          sent  on the black market. the fugitives came out of...
# 26       2.0          sent  on the black market. the fugitives came out of...
# 29       2.0          sent  to help in the struggle against the nazis. as ...
# 30       2.0          sent  to help in the struggle against the nazis. as ...
# 33       2.0      arranged  with the zionist underground. in the beginning...
# 35       2.0        rescue  he managed, which was situated only a few mete...
# 37       2.0      provided  with food and money. he also gave the jewish w...
# 39       2.0      employed  identity, he helped poor jews in the city with...
# 41       2.0        helped  german. at the beginning of the 1930s, pscheid...
# 44       3.0     sheltered  The Czeżowskis sheltered eight members of the ...
# 47       3.0      obtained  Professor Czezowski obtained “Aryan” documents...
# 50       4.0      arranged  being persecuted. i haven’t eaten for three da...
# 53       4.0      arranged  being persecuted. i haven’t eaten for three da...
# 55       4.0      arranged  being persecuted. i haven’t eaten for three da...
# 60       4.0      arranged  saving jews his life’s mission. he let his hou...
# 63       4.0      arranged  saving jews his life’s mission. he let his hou...
# 65       4.0      arranged  saving jews his life’s mission. he let his hou...
# 70       4.0      arranged  ghetto and, at great personal risk, smuggled o...
# 73       4.0      arranged  ghetto and, at great personal risk, smuggled o...
# 75       4.0      arranged  ghetto and, at great personal risk, smuggled o...
# 80       4.0       shelter  persecuted. i haven’t eaten for three days. pl...
# 83       4.0       shelter  persecuted. i haven’t eaten for three days. pl...
# 85       4.0       shelter  on, kowalski decided to make saving jews his l...
# 88       4.0       shelter  on, kowalski decided to make saving jews his l...
#
#                                 Rescuing_phrases-name        Full Name  \
# 0   Ludwig Wörl (1906-1967) was first arrested by ...      Ludwig Wörl
# 1   In 1942, Ludwig Wörl (1906-1967) was sent to A...      Ludwig Wörl
# 2   Ludwig Wörl (1906-1967) was first arrested by ...      Ludwig Wörl
# 3   In 1942, Ludwig Wörl (1906-1967) was sent to A...      Ludwig Wörl
# 4   Appointed as the Lagerälteste (the camp elder)...     Lagerälteste
# 6   Appointed as the Lagerälteste (the camp elder)...     Lagerälteste
# 9   Ludwig Wörl (1906-1967) also put Ludwig Wörl (...      Ludwig Wörl
# 11  Ludwig Wörl (1906-1967) also put Ludwig Wörl (...      Ludwig Wörl
# 13  Here, again, Wörl made Wörl beneficial influen...             Wörl
# 15  Ludwig Wörl (1906-1967) would forge selection ...      Ludwig Wörl
# 16  Here, again, Wörl made Wörl beneficial influen...             Wörl
# 18  Here, again, Wörl made Wörl beneficial influen...             Wörl
# 20  Even prisoners with tuberculosis were able to ...             None
# 21  Even prisoners with tuberculosis were able to ...             None
# 22  At the time of the evacuation of Auschwitz, Wö...             Wörl
# 23  After the war Wörl, who became chairman of the...             Wörl
# 25  Johann Pscheidt sent each one of The fugitives...  Johann Pscheidt
# 26  As part of the effort to locate Adolf Eichmann...   Adolf Eichmann
# 29  Johann Pscheidt sent each one of The fugitives...  Johann Pscheidt
# 30  As part of the effort to locate Adolf Eichmann...   Adolf Eichmann
# 33  In the beginning of 1943, when the Jews of the...  Johann Pscheidt
# 35  In the beginning of 1943, when the Jews of the...  Johann Pscheidt
# 37  Johann Pscheidt also gave the Jewish workers t...  Johann Pscheidt
# 39  Johann Pscheidt also gave the Jewish workers t...  Johann Pscheidt
# 41  Without revealing Johann Pscheidt identity, Jo...  Johann Pscheidt
# 44  Professor Czezowski also sheltered a Jewish re...        Czezowski
# 47  In time, Professor Czezowski obtained “Aryan” ...        Czezowski
# 50  Kowalski immediately did as requested, and arr...         Kowalski
# 53  Kowalski let a friend’s house be used as a she...         Kowalski
# 55  Before the deportation of the remnants of the ...         Kowalski
# 60  Kowalski immediately did as requested, and arr...         Kowalski
# 63  Kowalski let a friend’s house be used as a she...         Kowalski
# 65  Before the deportation of the remnants of the ...         Kowalski
# 70  Kowalski immediately did as requested, and arr...         Kowalski
# 73  Kowalski let a friend’s house be used as a she...         Kowalski
# 75  Before the deportation of the remnants of the ...         Kowalski
# 80  Kowalski immediately did as requested, and arr...         Kowalski
# 83  Kowalski let a friend’s house be used as a she...         Kowalski
# 85  Kowalski immediately did as requested, and arr...         Kowalski
# 88  Kowalski let a friend’s house be used as a she...         Kowalski
#
#       First Name Last Name
# 0         Ludwig      Wörl
# 1         Ludwig      Wörl
# 2         Ludwig      Wörl
# 3         Ludwig      Wörl
# 4   Lagerälteste      None
# 6   Lagerälteste      None
# 9         Ludwig      Wörl
# 11        Ludwig      Wörl
# 13          Wörl      None
# 15        Ludwig      Wörl
# 16          Wörl      None
# 18          Wörl      None
# 20          None      None
# 21          None      None
# 22          Wörl      None
# 23          Wörl      None
# 25        Johann  Pscheidt
# 26         Adolf  Eichmann
# 29        Johann  Pscheidt
# 30         Adolf  Eichmann
# 33        Johann  Pscheidt
# 35        Johann  Pscheidt
# 37        Johann  Pscheidt
# 39        Johann  Pscheidt
# 41        Johann  Pscheidt
# 44     Czezowski      None
# 47     Czezowski      None
# 50      Kowalski      None
# 53      Kowalski      None
# 55      Kowalski      None
# 60      Kowalski      None
# 63      Kowalski      None
# 65      Kowalski      None
# 70      Kowalski      None
# 73      Kowalski      None
# 75      Kowalski      None
# 80      Kowalski      None
# 83      Kowalski      None
# 85      Kowalski      None
# 88      Kowalski      None

# %%
table_5 = sample_table_4[['Story ID','Full Name', 'Last Name', 'First Name', 'Rescuing_phrases-name']]

# %%
table_5
# Out:
#     Story ID        Full Name Last Name    First Name  \
# 0        1.0      Ludwig Wörl      Wörl        Ludwig
# 1        1.0      Ludwig Wörl      Wörl        Ludwig
# 2        1.0      Ludwig Wörl      Wörl        Ludwig
# 3        1.0      Ludwig Wörl      Wörl        Ludwig
# 4        1.0     Lagerälteste      None  Lagerälteste
# 6        1.0     Lagerälteste      None  Lagerälteste
# 8        1.0             None      None          None
# 9        1.0      Ludwig Wörl      Wörl        Ludwig
# 11       1.0      Ludwig Wörl      Wörl        Ludwig
# 13       1.0             Wörl      None          Wörl
# 15       1.0      Ludwig Wörl      Wörl        Ludwig
# 16       1.0             Wörl      None          Wörl
# 18       1.0             Wörl      None          Wörl
# 20       1.0             None      None          None
# 21       1.0             None      None          None
# 22       1.0             Wörl      None          Wörl
# 23       1.0             Wörl      None          Wörl
# 25       2.0  Johann Pscheidt  Pscheidt        Johann
# 26       2.0   Adolf Eichmann  Eichmann         Adolf
# 29       2.0  Johann Pscheidt  Pscheidt        Johann
# 30       2.0   Adolf Eichmann  Eichmann         Adolf
# 33       2.0  Johann Pscheidt  Pscheidt        Johann
# 35       2.0  Johann Pscheidt  Pscheidt        Johann
# 37       2.0  Johann Pscheidt  Pscheidt        Johann
# 39       2.0  Johann Pscheidt  Pscheidt        Johann
# 41       2.0  Johann Pscheidt  Pscheidt        Johann
# 43       3.0             None      None          None
# 44       3.0        Czezowski      None     Czezowski
# 47       3.0        Czezowski      None     Czezowski
# 50       4.0         Kowalski      None      Kowalski
# 53       4.0         Kowalski      None      Kowalski
# 55       4.0         Kowalski      None      Kowalski
# 60       4.0         Kowalski      None      Kowalski
# 63       4.0         Kowalski      None      Kowalski
# 65       4.0         Kowalski      None      Kowalski
# 70       4.0         Kowalski      None      Kowalski
# 73       4.0         Kowalski      None      Kowalski
# 75       4.0         Kowalski      None      Kowalski
# 80       4.0         Kowalski      None      Kowalski
# 83       4.0         Kowalski      None      Kowalski
#
#                                 Rescuing_phrases-name
# 0   Ludwig Wörl (1906-1967) was first arrested by ...
# 1   In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 2   Ludwig Wörl (1906-1967) was first arrested by ...
# 3   In 1942, Ludwig Wörl (1906-1967) was sent to A...
# 4   Appointed as the Lagerälteste (the camp elder)...
# 6   Appointed as the Lagerälteste (the camp elder)...
# 8                                                 NaN
# 9   Ludwig Wörl (1906-1967) also put Ludwig Wörl (...
# 11  Ludwig Wörl (1906-1967) also put Ludwig Wörl (...
# 13  Here, again, Wörl made Wörl beneficial influen...
# 15  Ludwig Wörl (1906-1967) would forge selection ...
# 16  Here, again, Wörl made Wörl beneficial influen...
# 18  Here, again, Wörl made Wörl beneficial influen...
# 20  Even prisoners with tuberculosis were able to ...
# 21  Even prisoners with tuberculosis were able to ...
# 22  At the time of the evacuation of Auschwitz, Wö...
# 23  After the war Wörl, who became chairman of the...
# 25  Johann Pscheidt sent each one of The fugitives...
# 26  As part of the effort to locate Adolf Eichmann...
# 29  Johann Pscheidt sent each one of The fugitives...
# 30  As part of the effort to locate Adolf Eichmann...
# 33  In the beginning of 1943, when the Jews of the...
# 35  In the beginning of 1943, when the Jews of the...
# 37  Johann Pscheidt also gave the Jewish workers t...
# 39  Johann Pscheidt also gave the Jewish workers t...
# 41  Without revealing Johann Pscheidt identity, Jo...
# 43                                                NaN
# 44  Professor Czezowski also sheltered a Jewish re...
# 47  In time, Professor Czezowski obtained “Aryan” ...
# 50  Kowalski immediately did as requested, and arr...
# 53  Kowalski let a friend’s house be used as a she...
# 55  Before the deportation of the remnants of the ...
# 60  Kowalski immediately did as requested, and arr...
# 63  Kowalski let a friend’s house be used as a she...
# 65  Before the deportation of the remnants of the ...
# 70  Kowalski immediately did as requested, and arr...
# 73  Kowalski let a friend’s house be used as a she...
# 75  Before the deportation of the remnants of the ...
# 80  Kowalski immediately did as requested, and arr...
# 83  Kowalski let a friend’s house be used as a she...

# %%
table_5.to_csv('3415_SPACY_All_Rescuers.xlsx', index = False)

# %% [markdown]
# ### Rescuing DATE

# %%
# Function to find the full name of the rescuer, first name, last name, and the rescued date
def extract_name_and_date(row):
    sentence = row['Rescuing_phrases-name']  # Adjusted column name
    rescuing_verb = row['Rescuing Verb']    # Adjusted column name
    
    # Skip NaN values
    if pd.isna(sentence):
        return pd.Series([None, None, None, None])  # Return None for all if sentence is NaN
    
    # Process sentence with Spacy
    doc = nlp(sentence)
    
    # Extract full name (PERSON) and rescued date (DATE)
    full_name = None
    rescued_date = None
    for ent in doc.ents:
        if ent.label_ == "PERSON" and full_name is None:  # Get the first PERSON entity
            full_name = ent.text
        if ent.label_ == "DATE" and rescued_date is None:  # Get the first DATE entity
            rescued_date = ent.text

    if not full_name:
        return pd.Series([None, None, None, rescued_date])  # Return None for names if no PERSON found
    
    # Split the full name into first name and last name
    name_parts = full_name.split()
    if len(name_parts) > 1:
        last_name = name_parts[-1]
        first_name = " ".join(name_parts[:-1])
    else:
        first_name = full_name
        last_name = None  # If no last name, leave it as None
    
    return pd.Series([full_name, first_name, last_name, rescued_date])

# %%
# Apply the function to the DataFrame and store the results in separate columns
sample_table_4[['Full Name', 'First Name', 'Last Name', 'Rescued Date']] = sample_table_4.apply(extract_name_and_date, axis=1)
# Out:
# /Users/minjoo/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
sample_table_4
# Out:
#     Story ID        Rescuing Verb  \
# 0        1.0                 sent
# 1        1.0                 sent
# 2        1.0                 sent
# 3        1.0                 sent
# 4        1.0             employed
# 6        1.0               saving
# 8        1.0  put himself at risk
# 9        1.0               obtain
# 11       1.0            treatment
# 13       1.0            treatment
# 15       1.0                forge
# 16       1.0            influence
# 18       1.0           protecting
# 20       1.0             exempted
# 21       1.0            protected
# 22       1.0               helped
# 23       1.0            dedicated
# 25       2.0                 sent
# 26       2.0                 sent
# 29       2.0                 sent
# 30       2.0                 sent
# 33       2.0             arranged
# 35       2.0               rescue
# 37       2.0             provided
# 39       2.0             employed
# 41       2.0               helped
# 43       3.0             smuggled
# 44       3.0            sheltered
# 47       3.0             obtained
# 50       4.0             arranged
# 53       4.0             arranged
# 55       4.0             arranged
# 60       4.0             arranged
# 63       4.0             arranged
# 65       4.0             arranged
# 70       4.0             arranged
# 73       4.0             arranged
# 75       4.0             arranged
# 80       4.0              shelter
# 83       4.0              shelter
#
#                                       Rescuing Phrase  \
# 0   his life as a political prisoner in nazi conce...
# 1   his life as a political prisoner in nazi conce...
# 2   to the camp’s joinery and later, as a trained ...
# 3   to the camp’s joinery and later, as a trained ...
# 4   personnel. appointed as the lagerälteste (the ...
# 6   lagerälteste (the camp elder) of the hospital ...
# 8   barracks, wörl, against the express orders of ...
# 9   the ss, employed jewish doctors, thus saving t...
# 11  himself at risk in order to obtain at least a ...
# 13  himself at risk in order to obtain at least a ...
# 15  obtain at least a minimum of the required medi...
# 16  german descent and seniority, put in charge of...
# 18  and seniority, put in charge of güntergrube, a...
# 20  that they get their due share of food and clot...
# 21  of food and clothing. even prisoners with tube...
# 22  them by various subterfuges from the inspectio...
# 23  the infamous death marches. after the war wörl...
# 25  on the black market. the fugitives came out of...
# 26  on the black market. the fugitives came out of...
# 29  to help in the struggle against the nazis. as ...
# 30  to help in the struggle against the nazis. as ...
# 33  with the zionist underground. in the beginning...
# 35  he managed, which was situated only a few mete...
# 37  with food and money. he also gave the jewish w...
# 39  identity, he helped poor jews in the city with...
# 41  german. at the beginning of the 1930s, pscheid...
# 43  The Czeżowskis smuggled food into the ghetto f...
# 44  The Czeżowskis sheltered eight members of the ...
# 47  Professor Czezowski obtained “Aryan” documents...
# 50  being persecuted. i haven’t eaten for three da...
# 53  being persecuted. i haven’t eaten for three da...
# 55  being persecuted. i haven’t eaten for three da...
# 60  saving jews his life’s mission. he let his hou...
# 63  saving jews his life’s mission. he let his hou...
# 65  saving jews his life’s mission. he let his hou...
# 70  ghetto and, at great personal risk, smuggled o...
# 73  ghetto and, at great personal risk, smuggled o...
# 75  ghetto and, at great personal risk, smuggled o...
# 80  persecuted. i haven’t eaten for three days. pl...
# 83  persecuted. i haven’t eaten for three days. pl...
#
#                                 Rescuing_phrases-name        Full Name  \
# 0   Ludwig Wörl (1906-1967) was first arrested by ...      Ludwig Wörl
# 1   In 1942, Ludwig Wörl (1906-1967) was sent to A...      Ludwig Wörl
# 2   Ludwig Wörl (1906-1967) was first arrested by ...      Ludwig Wörl
# 3   In 1942, Ludwig Wörl (1906-1967) was sent to A...      Ludwig Wörl
# 4   Appointed as the Lagerälteste (the camp elder)...     Lagerälteste
# 6   Appointed as the Lagerälteste (the camp elder)...     Lagerälteste
# 8                                                 NaN             None
# 9   Ludwig Wörl (1906-1967) also put Ludwig Wörl (...      Ludwig Wörl
# 11  Ludwig Wörl (1906-1967) also put Ludwig Wörl (...      Ludwig Wörl
# 13  Here, again, Wörl made Wörl beneficial influen...             Wörl
# 15  Ludwig Wörl (1906-1967) would forge selection ...      Ludwig Wörl
# 16  Here, again, Wörl made Wörl beneficial influen...             Wörl
# 18  Here, again, Wörl made Wörl beneficial influen...             Wörl
# 20  Even prisoners with tuberculosis were able to ...             None
# 21  Even prisoners with tuberculosis were able to ...             None
# 22  At the time of the evacuation of Auschwitz, Wö...             Wörl
# 23  After the war Wörl, who became chairman of the...             Wörl
# 25  Johann Pscheidt sent each one of The fugitives...  Johann Pscheidt
# 26  As part of the effort to locate Adolf Eichmann...   Adolf Eichmann
# 29  Johann Pscheidt sent each one of The fugitives...  Johann Pscheidt
# 30  As part of the effort to locate Adolf Eichmann...   Adolf Eichmann
# 33  In the beginning of 1943, when the Jews of the...  Johann Pscheidt
# 35  In the beginning of 1943, when the Jews of the...  Johann Pscheidt
# 37  Johann Pscheidt also gave the Jewish workers t...  Johann Pscheidt
# 39  Johann Pscheidt also gave the Jewish workers t...  Johann Pscheidt
# 41  Without revealing Johann Pscheidt identity, Jo...  Johann Pscheidt
# 43                                                NaN             None
# 44  Professor Czezowski also sheltered a Jewish re...        Czezowski
# 47  In time, Professor Czezowski obtained “Aryan” ...        Czezowski
# 50  Kowalski immediately did as requested, and arr...         Kowalski
# 53  Kowalski let a friend’s house be used as a she...         Kowalski
# 55  Before the deportation of the remnants of the ...         Kowalski
# 60  Kowalski immediately did as requested, and arr...         Kowalski
# 63  Kowalski let a friend’s house be used as a she...         Kowalski
# 65  Before the deportation of the remnants of the ...         Kowalski
# 70  Kowalski immediately did as requested, and arr...         Kowalski
# 73  Kowalski let a friend’s house be used as a she...         Kowalski
# 75  Before the deportation of the remnants of the ...         Kowalski
# 80  Kowalski immediately did as requested, and arr...         Kowalski
# 83  Kowalski let a friend’s house be used as a she...         Kowalski
#
#       First Name Last Name           Rescued Date
# 0         Ludwig      Wörl              1906-1967
# 1         Ludwig      Wörl                   1942
# 2         Ludwig      Wörl              1906-1967
# 3         Ludwig      Wörl                   1942
# 4   Lagerälteste      None                   None
# 6   Lagerälteste      None                   None
# 8           None      None                   None
# 9         Ludwig      Wörl              1906-1967
# 11        Ludwig      Wörl              1906-1967
# 13          Wörl      None                   None
# 15        Ludwig      Wörl              1906-1967
# 16          Wörl      None                   None
# 18          Wörl      None                   None
# 20          None      None                   None
# 21          None      None                   None
# 22          Wörl      None                   None
# 23          Wörl      None                   None
# 25        Johann  Pscheidt                   None
# 26         Adolf  Eichmann                   None
# 29        Johann  Pscheidt                   None
# 30         Adolf  Eichmann                   None
# 33        Johann  Pscheidt  the beginning of 1943
# 35        Johann  Pscheidt  the beginning of 1943
# 37        Johann  Pscheidt                   None
# 39        Johann  Pscheidt                   None
# 41        Johann  Pscheidt                   None
# 43          None      None                   None
# 44     Czezowski      None              July 1944
# 47     Czezowski      None                   None
# 50      Kowalski      None                   None
# 53      Kowalski      None                   None
# 55      Kowalski      None                   None
# 60      Kowalski      None                   None
# 63      Kowalski      None                   None
# 65      Kowalski      None                   None
# 70      Kowalski      None                   None
# 73      Kowalski      None                   None
# 75      Kowalski      None                   None
# 80      Kowalski      None                   None
# 83      Kowalski      None                   None

# %%
table_6.to_csv('3415_SPACY_All_Rescuers_Dates.xlsx', index = False)

# %%
# 문장 처리
# doc = nlp(sentence)

# 사람(Entity) 추출
people = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]
print("Detected people:", people)

# 의존성 파싱으로 주어-동사 관계 분석
for token in doc:
    if token.dep_ == "nsubj" and token.head.lemma_ == "help":
        print(f"Subject: {token.text}, Verb: {token.head.text}")
# Out:
# Detected people: ['Vashem', 'Werner Krumme']

# %%
3415_SPACY_All_Rescuers.XLS

# %%
output_file_name = '3415_SPACY_All_Names.xlsx'
output.to_csv(f'./output/{output_file_name}')
